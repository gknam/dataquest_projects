# %% [markdown]
# https://www.dataquest.io/m/215/guided-project%3A-preparing-data-for-sqlite
#
# A cleaned up and transformed version of [Academy Award nominations and winners dataset](https://www.aggdata.com/awards/oscar) will be used.
#
# # 1. Introduction to the data
#
# The dataset shows info on Academy Award nominations upto the year 2010.
#
# This project will extract rows only for actors and actresses categories between the years 2001 and 2010. Then, they will be added to a SQLite table.
#
# ## 1.1. Quick glance at the data
#
# This is a preview of the data.

# %%
import pandas as pd
from IPython.display import display
from pprint import pprint

# read in dataset
df = pd.read_csv("academy_awards.csv", encoding="ISO-8859-1")

# show top five rows of data
display(df.head())
# Out:
#           Year               Category          Nominee  \
# 0  2010 (83rd)  Actor -- Leading Role    Javier Bardem
# 1  2010 (83rd)  Actor -- Leading Role     Jeff Bridges
# 2  2010 (83rd)  Actor -- Leading Role  Jesse Eisenberg
# 3  2010 (83rd)  Actor -- Leading Role      Colin Firth
# 4  2010 (83rd)  Actor -- Leading Role     James Franco
#
#                           Additional Info Won? Unnamed: 5 Unnamed: 6  \
# 0                      Biutiful {'Uxbal'}   NO        NaN        NaN
# 1           True Grit {'Rooster Cogburn'}   NO        NaN        NaN
# 2  The Social Network {'Mark Zuckerberg'}   NO        NaN        NaN
# 3    The King's Speech {'King George VI'}  YES        NaN        NaN
# 4              127 Hours {'Aron Ralston'}   NO        NaN        NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0        NaN        NaN        NaN         NaN
# 1        NaN        NaN        NaN         NaN
# 2        NaN        NaN        NaN         NaN
# 3        NaN        NaN        NaN         NaN
# 4        NaN        NaN        NaN         NaN

# %%
# show column names
pprint(df.columns.tolist())
# Out:
# ['Year',
#  'Category',
#  'Nominee',
#  'Additional Info',
#  'Won?',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10']

# %% [markdown]
# ## 1.2. Explore data further
#
# ### 1.2.1. "Unnamed: " columns
#
# From the preview above, the "Unnamed: " columns seem not useful.
#
# To check whether this is true, displayed below are the counts of each unique value in these columns.

# %%
# check values of "Unnamed: 5" columns
pprint(df["Unnamed: 5"].value_counts())
# Out:
# *                                                                                                               7
#  discoverer of stars                                                                                            1
#  error-prone measurements on sets. [Digital Imaging Technology]"                                                1
#  D.B. "Don" Keele and Mark E. Engebretson has resulted in the over 20-year dominance of constant-directivity    1
#  resilience                                                                                                     1
# Name: Unnamed: 5, dtype: int64

# %%
# check values of "Unnamed: 6" columns
pprint(df["Unnamed: 6"].value_counts())
# Out:
# *                                                                   9
#  sympathetic                                                        1
#  flexibility and water resistance                                   1
#  direct radiator bass style cinema loudspeaker systems. [Sound]"    1
# Name: Unnamed: 6, dtype: int64

# %%
# check values of "Unnamed: 7" columns
pprint(df["Unnamed: 7"].value_counts())
# Out:
# *                                                     1
#  kindly                                               1
#  while requiring no dangerous solvents. [Systems]"    1
# Name: Unnamed: 7, dtype: int64

# %%
# check values of "Unnamed: 8" columns
pprint(df["Unnamed: 8"].value_counts())
# Out:
# *                                                 1
#  understanding comedy genius - Mack Sennett.""    1
# Name: Unnamed: 8, dtype: int64

# %%
# check values of "Unnamed: 9" columns
pprint(df["Unnamed: 9"].value_counts())
# Out:
# *    1
# Name: Unnamed: 9, dtype: int64

# %%
# check values of "Unnamed: 10" columns
pprint(df["Unnamed: 10"].value_counts())
# Out:
# *    1
# Name: Unnamed: 10, dtype: int64

# %% [markdown]
# It can now be confirmed that the "Unnamed: " columns can be discarded.
#
# # 2. Filtering the data
#
#
# Extract the rows where (1) years range from 2001 to 2010 (2) for actor and actress categories.
#
#
# ## 2.1. Modify "Year" column
#
# The "Year" column will be adjusted so that it becomes 4-digit integer values representing years.

# %%
# Simplify "Year" column (e.g. "2010 (83rd)" --> "2010")
df["Year"] = df["Year"].str.slice(start=0, stop=4)

# Convert format (string --> integer)
df["Year"] = df["Year"].astype("int64")

# Show first 5 rows of "Year" column
df["Year"].head()
# Out:
# 0    2010
# 1    2010
# 2    2010
# 3    2010
# 4    2010
# Name: Year, dtype: int64

# %% [markdown]
# ## 2.2. Filter dataset by year and category
#
# [`pandas.Series.isin`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.isin.html) is used for filtering by category.

# %%
# 1. Extract rows for years 2001 and later
later_than_2000 = df[df["Year"] > 2000]

# 2. Extract nominations for actors and actresses
award_categories = ["Actor -- Leading Role", 
                    "Actor -- Supporting Role", 
                    "Actress -- Leading Role", 
                    "Actress -- Supporting Role"]

nominations = later_than_2000[later_than_2000["Category"].isin(award_categories)]

# %% [markdown]
# # 3. Cleaning up the Won? and Unnamed columns
#
# Values in "Won?" column will be converted ("Yes" --> 1; "NO" --> 0) so that they are compatible with SQLite. I will use [`pandas.Series.map`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.map.html) for the conversion.
#
# Then, the column will be renamed as "Won".

# %%
# Turn off "SettingWithCopyWarning" warning (https://stackoverflow.com/a/20627316)
# (if not turned off, the next two cells will create a warning message.)
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# convert values
def convert(string):
    """
    Convert strings
    "YES" --> 1
    "NO" --> 0
    Any other values are untouched.
    """
    
    conv_dic = {"YES": 1, 
               "NO": 0}
    
    output = conv_dic[string] if string in conv_dic \
                              else string
    
    return output

nominations["Won?"] = nominations["Won?"].map(convert)

# %%
# Rename columns
nominations["Won"] = nominations["Won?"]
final_nominations = nominations.drop(labels=['Won?', 
                          'Unnamed: 5',
                          'Unnamed: 6',
                          'Unnamed: 7',
                          'Unnamed: 8',
                          'Unnamed: 9',
                          'Unnamed: 10'],
                 axis=1)

# show first five rows of filtered dataset
final_nominations.head()
# Out:
#    Year               Category          Nominee  \
# 0  2010  Actor -- Leading Role    Javier Bardem
# 1  2010  Actor -- Leading Role     Jeff Bridges
# 2  2010  Actor -- Leading Role  Jesse Eisenberg
# 3  2010  Actor -- Leading Role      Colin Firth
# 4  2010  Actor -- Leading Role     James Franco
#
#                           Additional Info  Won
# 0                      Biutiful {'Uxbal'}    0
# 1           True Grit {'Rooster Cogburn'}    0
# 2  The Social Network {'Mark Zuckerberg'}    0
# 3    The King's Speech {'King George VI'}    1
# 4              127 Hours {'Aron Ralston'}    0

# %% [markdown]
# # 4. Cleaning up the Additional Info column
#
# Values in the "Additional Info" column (e.g. "Biutiful {'Uxbal'}") will be split into two columns so that one column will contain the movie title ("Biutiful") and the other the character name ("Uxbal").
#
# First, I will check if all rows can be splitted with " {'" and "'}".

# %%
# do all rows contain " {'"?
print(final_nominations["Additional Info"].str.contains(" {'").unique())

# do all rows end with "'}"?
print(final_nominations["Additional Info"].str.endswith("'}").unique())
# Out:
# [ True]
# [ True]

# %% [markdown]
# It's safe to do so.
#
# Now, each row will be splitted and saved into "Movie" and "Character" columns, which will replace the current "Additional Info" column.

# %%
# strip "'}"
additional_info_one = final_nominations["Additional Info"].str.rstrip("'}")

# split by " {'"
additional_info_two = additional_info_one.str.split(" {'")

# add splitted values into Movie and Character columns
movie_names = additional_info_two.str[0]
characters = additional_info_two.str[1]

final_nominations["Movie"] = movie_names
final_nominations["Character"] = characters

# remove Additional Info column
final_nominations.drop(labels="Additional Info", axis=1, inplace=True)

# show first five rows of dataset
final_nominations.head()
# Out:
#    Year               Category          Nominee  Won               Movie  \
# 0  2010  Actor -- Leading Role    Javier Bardem    0            Biutiful
# 1  2010  Actor -- Leading Role     Jeff Bridges    0           True Grit
# 2  2010  Actor -- Leading Role  Jesse Eisenberg    0  The Social Network
# 3  2010  Actor -- Leading Role      Colin Firth    1   The King's Speech
# 4  2010  Actor -- Leading Role     James Franco    0           127 Hours
#
#          Character
# 0            Uxbal
# 1  Rooster Cogburn
# 2  Mark Zuckerberg
# 3   King George VI
# 4     Aron Ralston

# %% [markdown]
# # 5. Exporting to SQLite

# %%
import sqlite3

# connect to database
conn = sqlite3.connect("nominations.db")

# create table
final_nominations.to_sql(name="nominations", con=conn, index=False, if_exists="replace")

# %% [markdown]
# # 6. Verifying in SQL
#
# This section verifies that the transfer from Pandas data frame into a table in a SQLite database.

# %%
cursor = conn.cursor()

# show table schema
query = "PRAGMA table_info(nominations)"
cursor.execute(query)
pprint(cursor.fetchall())
# Out:
# [(0, 'Year', 'INTEGER', 0, None, 0),
#  (1, 'Category', 'TEXT', 0, None, 0),
#  (2, 'Nominee', 'TEXT', 0, None, 0),
#  (3, 'Won', 'INTEGER', 0, None, 0),
#  (4, 'Movie', 'TEXT', 0, None, 0),
#  (5, 'Character', 'TEXT', 0, None, 0)]

# %%
# show first five rows of table in the SQLite database
query = "SELECT * FROM nominations LIMIT 10"

cursor.execute(query)
pprint(cursor.fetchall())

# close connection to database
conn.close()
# Out:
# [(2010, 'Actor -- Leading Role', 'Javier Bardem', 0, 'Biutiful', 'Uxbal'),
#  (2010,
#   'Actor -- Leading Role',
#   'Jeff Bridges',
#   0,
#   'True Grit',
#   'Rooster Cogburn'),
#  (2010,
#   'Actor -- Leading Role',
#   'Jesse Eisenberg',
#   0,
#   'The Social Network',
#   'Mark Zuckerberg'),
#  (2010,
#   'Actor -- Leading Role',
#   'Colin Firth',
#   1,
#   "The King's Speech",
#   'King George VI'),
#  (2010,
#   'Actor -- Leading Role',
#   'James Franco',
#   0,
#   '127 Hours',
#   'Aron Ralston'),
#  (2010,
#   'Actor -- Supporting Role',
#   'Christian Bale',
#   1,
#   'The Fighter',
#   'Dicky Eklund'),
#  (2010,
#   'Actor -- Supporting Role',
#   'John Hawkes',
#   0,
#   "Winter's Bone",
#   'Teardrop'),
#  (2010,
#   'Actor -- Supporting Role',
#   'Jeremy Renner',
#   0,
#   'The Town',
#   'James Coughlin'),
#  (2010,
#   'Actor -- Supporting Role',
#   'Mark Ruffalo',
#   0,
#   'The Kids Are All Right',
#   'Paul'),
#  (2010,
#   'Actor -- Supporting Role',
#   'Geoffrey Rush',
#   0,
#   "The King's Speech",
#   'Lionel Logue')]

# %% [markdown]
# # 7. Further questions
#
# Following are further questions put forward by DataQuest. I will not apply these to the current output, but only try to answer the questions.
#
# ## 7.1. The awards categories in older ceremonies were different than the ones we have today. What relevant information should we keep from older ceremonies?
#
# First, I will display for each category from pre-2001 record.

# %%
# get categories of pre-2001 ceremonies
cat_pre2001 = set(df[df["Year"] < 2001]["Category"].unique().tolist())

# get categories of 2001-2010 ceremonies
cat_2001_2010 = set(df[df["Year"] >= 2001]["Category"].unique().tolist())

# get categories existing only in pre-2001 categories
cat_pre2001_only = cat_pre2001 - cat_2001_2010
pprint(cat_pre2001_only)
# Out:
# {'Acting (other)',
#  'Assistant Director (archaic category)',
#  'Dance Direction (archaic category)',
#  'Documentary (other)',
#  'Engineering Effects (archaic category)',
#  'Special Achievement Award',
#  'Special Effects (archaic category)',
#  'Unique and Artistic Picture (archaic category)'}

# %% [markdown]
# Now, two rows per category will be displayed for pre-2001 record: one row with null "Additional Info", and another with non-null "Additional Info".

# %%
df_pre2011_only = df[df["Category"].isin(cat_pre2001_only)][["Year", "Category", "Nominee", "Additional Info"]]

# get all categories
cats = df_pre2011_only["Category"].value_counts().index

# display one null and one non-null rows from each category
for i in cats:
    df1 = df[(df["Category"] == i) & (pd.notna(df["Additional Info"]))]\
          [["Year", "Category", "Nominee", "Additional Info"]].head(1)
    df2 = df[(df["Category"] == i) & (pd.isnull(df["Additional Info"]))]\
          [["Year", "Category", "Nominee", "Additional Info"]].head(1)
    display(df1.append(df2))
# Out:
#       Year                            Category  \
# 6075  1962  Special Effects (archaic category)
# 9442  1938  Special Effects (archaic category)
#
#                                                 Nominee  \
# 6075                                    The Longest Day
# 9442  For outstanding achievement in creating Specia...
#
#                                         Additional Info
# 6075  Visual Effects by Robert MacDonald; Audible Ef...
# 9442                                                NaN
#       Year                               Category            Nominee  \
# 9566  1937  Assistant Director (archaic category)     In Old Chicago
# 9903  1932  Assistant Director (archaic category)  Percy Ikerd (Fox)
#
#      Additional Info
# 9566     Robert Webb
# 9903             NaN
#       Year             Category                     Nominee    Additional Info
# 8657  1942  Documentary (other)  Africa, Prelude to Victory  The March of Time
#       Year                            Category  \
# 9572  1937  Dance Direction (archaic category)
# 9571  1937  Dance Direction (archaic category)
#
#                                                 Nominee     Additional Info
# 9572  Bobby Connolly -- Too Marvelous for Words" num...   Willing and Able"
# 9571  Busby Berkeley -- The Finale" number from Vars...                 NaN
#       Year                   Category  \
# 2721  1990  Special Achievement Award
# 2081  1995  Special Achievement Award
#
#                                                 Nominee  \
# 2721                                       Total Recall
# 2081  To John Lasseter, for his inspired leadership ...
#
#                                         Additional Info
# 2721  Eric Brevig, Rob Bottin, Tim McGovern, Alex Funke
# 2081                                                NaN
#       Year        Category                                            Nominee  \
# 6226  1960  Acting (other)  To Hayley Mills for Pollyanna, the most outsta...
#
#      Additional Info
# 6226             NaN
#        Year                                        Category Nominee  \
# 10134  1927  Unique and Artistic Picture (archaic category)     Fox
#
#       Additional Info
# 10134         Sunrise
#        Year                                Category  \
# 10132  1927  Engineering Effects (archaic category)
# 10131  1927  Engineering Effects (archaic category)
#
#                                                  Nominee Additional Info
# 10132                                        Roy Pomeroy           Wings
# 10131  Ralph Hammeras [NOTE: This nomination was not ...             NaN

# %% [markdown]
# As this project focuses on awards for acting, I will consider only "Acting (other)" category useful. Let's take a look at all of them.

# %% [markdown]
# <a name="act_other_table"></a>

# %%
df_pre2011_only[df_pre2011_only["Category"] == "Acting (other)"]
# Out:
#        Year        Category  \
# 6226   1960  Acting (other)
# 6966   1954  Acting (other)
# 6967   1954  Acting (other)
# 7623   1949  Acting (other)
# 7745   1948  Acting (other)
# 7860   1947  Acting (other)
# 7974   1946  Acting (other)
# 7975   1946  Acting (other)
# 8089   1945  Acting (other)
# 8252   1944  Acting (other)
# 9165   1939  Acting (other)
# 9318   1938  Acting (other)
# 9795   1934  Acting (other)
# 10104  1927  Acting (other)
#
#                                                  Nominee Additional Info
# 6226   To Hayley Mills for Pollyanna, the most outsta...             NaN
# 6966   To Jon Whiteley for his outstanding juvenile p...             NaN
# 6967   To Vincent Winter for his outstanding juvenile...             NaN
# 7623   To Bobby Driscoll, as the outstanding juvenile...             NaN
# 7745   To Ivan Jandl, for the outstanding juvenile pe...             NaN
# 7860   To James Baskett for his able and heart-warmin...             NaN
# 7974   To Harold Russell for bringing hope and courag...             NaN
# 7975   To Claude Jarman, Jr., outstanding child actor...             NaN
# 8089   To Peggy Ann Garner, outstanding child actress...             NaN
# 8252   To Margaret O'Brien, outstanding child actress...             NaN
# 9165   To Judy Garland for her outstanding performanc...             NaN
# 9318   To Deanna Durbin and Mickey Rooney for their s...             NaN
# 9795   To Shirley Temple, in grateful recognition of ...             NaN
# 10104  To Charles Chaplin, for acting, writing, direc...             NaN

# %% [markdown]
# Unlike other acting categories, the "Additional Info" column does not include movie titles and character names.
#
# Below is the full list of "Nominees" values for "Acting (other)" category.

# %% [markdown]
# <a name="act_other_nominee"></a>

# %%
for i, s in df_pre2011_only[df_pre2011_only["Category"] == "Acting (other)"].iterrows():
    print(s["Nominee"])
# Out:
# To Hayley Mills for Pollyanna, the most outstanding juvenile performance during 1960.
# To Jon Whiteley for his outstanding juvenile performance in The Little Kidnappers.
# To Vincent Winter for his outstanding juvenile performance in The Little Kidnappers.
# To Bobby Driscoll, as the outstanding juvenile actor of 1949.
# To Ivan Jandl, for the outstanding juvenile performance of 1948, as Karel Malik" in The Search."
# To James Baskett for his able and heart-warming characterization of Uncle Remus, friend and story teller to the children of the world in Walt Disney's Song of the South.
# To Harold Russell for bringing hope and courage to his fellow veterans through his appearance in The Best Years of Our Lives.
# To Claude Jarman, Jr., outstanding child actor of 1946.
# To Peggy Ann Garner, outstanding child actress of 1945.
# To Margaret O'Brien, outstanding child actress of 1944.
# To Judy Garland for her outstanding performance as a screen juvenile during the past year.
# To Deanna Durbin and Mickey Rooney for their significant contribution in bringing to the screen the spirit and personification of youth, and as juvenile players setting a high standard of ability and achievement.
# To Shirley Temple, in grateful recognition of her outstanding contribution to screen entertainment during the year 1934.
# To Charles Chaplin, for acting, writing, directing and producing The Circus.[NOTE: The Academy Board of Judges on merit awards for individual achievements in motion picture arts during the year ending August 1, 1928, unanimously decided that your name should be removed from the competitive classes, and that a special first award be conferred upon you for writing, acting, directing and producing The Circus. The collective accomplishments thus displayed place you in a class by yourself. (Letter from the Academy to Mr. Chaplin, dated February 19, 1929.)]

# %% [markdown]
# What we could add to the current project (which I will not) are movie titles included in some rows and character
# names included in very few.
#
# ## 7.2. What are all the different formatting styles that the Additional Info column contains? Can we use tools like regular expressions to capture these patterns and clean them up?
#
# Now, two rows per category will be displayed: one row with null "Additional Info", and another with non-null "Additional Info".

# %%
# get all categories
cats = df["Category"].value_counts().index

# display one null and one non-null rows from each category
for i in cats:
    df1 = df[(df["Category"] == i) & (pd.notna(df["Additional Info"]))]\
          [["Year", "Category", "Additional Info"]].head(1)
    df2 = df[(df["Category"] == i) & (pd.isnull(df["Additional Info"]))]\
          [["Year", "Category", "Additional Info"]].head(1)
    display(df1.append(df2))
# Out:
#        Year Category                            Additional Info
# 110    2010  Writing  Screenplay by Danny Boyle & Simon Beaufoy
# 10126  1927  Writing                                        NaN
#     Year         Category Additional Info
# 66  2010  Music (Scoring)     John Powell
#       Year        Category    Additional Info
# 28    2010  Cinematography  Matthew Libatique
# 9342  1938  Cinematography                NaN
#       Year       Category                                    Additional Info
# 23    2010  Art Direction  Production Design: Robert Stromberg; Set Decor...
# 8260  1944  Art Direction                                                NaN
#     Year      Category                                    Additional Info
# 75  2010  Best Picture  Mike Medavoy, Brian Oliver and Scott Franklin,...
#       Year Category                               Additional Info
# 95    2010    Sound  Lora Hirschberg, Gary A. Rizzo and Ed Novick
# 9954  1931    Sound                                           NaN
#     Year                  Category Additional Info
# 90  2010  Short Film (Live Action)      Tanel Toom
#      Year                                           Category  \
# 132  2010  Scientific and Technical (Technical Achievemen...
# 128  2010  Scientific and Technical (Technical Achievemen...
#
#                                        Additional Info
# 132   was shared with the industry in their technic...
# 128                                                NaN
#     Year      Category                                    Additional Info
# 71  2010  Music (Song)  Music and Lyric by Tom Douglas, Troy Verges an...
#     Year                 Category                 Additional Info
# 10  2010  Actress -- Leading Role  The Kids Are All Right {'Nic'}
#        Year   Category   Additional Info
# 38     2010  Directing  Darren Aronofsky
# 10116  1927  Directing               NaN
#        Year               Category     Additional Info
# 0      2010  Actor -- Leading Role  Biutiful {'Uxbal'}
# 10100  1927  Actor -- Leading Role                 NaN
#     Year      Category  Additional Info
# 53  2010  Film Editing  Andrew Weisblum
#     Year        Category Additional Info
# 33  2010  Costume Design  Colleen Atwood
#     Year                    Category                   Additional Info
# 15  2010  Actress -- Supporting Role  The Fighter {'Charlene Fleming'}
#    Year                  Category               Additional Info
# 5  2010  Actor -- Supporting Role  The Fighter {'Dicky Eklund'}
#     Year               Category Additional Info
# 85  2010  Short Film (Animated)    Teddy Newton
#     Year                     Category Additional Info
# 48  2010  Documentary (Short Subject)   Jed Rothstein
#       Year               Category           Additional Info
# 43    2010  Documentary (Feature)  Banksy and Jaimie D'Cruz
# 8847  1941  Documentary (Feature)                       NaN
#       Year               Category Additional Info
# 58    2010  Foreign Language Film          Mexico
# 6879  1955  Foreign Language Film             NaN
#      Year                                           Category  \
# 764  2005  Scientific and Technical (Scientific and Engin...
# 124  2010  Scientific and Technical (Scientific and Engin...
#
#                                        Additional Info
# 764   providing the key in demonstrating to the ind...
# 124                                                NaN
#       Year        Category          Additional Info
# 6669  1957  Honorary Award   motion picture pioneer
# 120   2010  Honorary Award                      NaN
#      Year        Category                                    Additional Info
# 105  2010  Visual Effects  Ken Ralston, David Schaub, Carey Villegas and ...
#      Year       Category Additional Info
# 100  2010  Sound Editing    Richard King
#       Year                            Category  \
# 6075  1962  Special Effects (archaic category)
# 9442  1938  Special Effects (archaic category)
#
#                                         Additional Info
# 6075  Visual Effects by Robert MacDonald; Audible Ef...
# 9442                                                NaN
#       Year Category Additional Info
# 63    2010   Makeup    Adrien Morot
# 5267  1968   Makeup             NaN
#      Year                                           Category Additional Info
# 507  2007  Scientific and Technical (Academy Award of Merit)             NaN
#      Year                           Category Additional Info
# 123  2010  Irving G. Thalberg Memorial Award             NaN
#       Year               Category                 Additional Info
# 20    2010  Animated Feature Film  Chris Sanders and Dean DeBlois
# 1987  1995  Animated Feature Film                             NaN
#       Year                               Category Additional Info
# 9566  1937  Assistant Director (archaic category)     Robert Webb
# 9903  1932  Assistant Director (archaic category)             NaN
#      Year                                 Category Additional Info
# 134  2010  Scientific and Technical (Bonner Medal)             NaN
#      Year                          Category Additional Info
# 386  2008  Jean Hersholt Humanitarian Award             NaN
#       Year             Category    Additional Info
# 8657  1942  Documentary (other)  The March of Time
#       Year                            Category     Additional Info
# 9572  1937  Dance Direction (archaic category)   Willing and Able"
# 9571  1937  Dance Direction (archaic category)                 NaN
#      Year                                           Category Additional Info
# 391  2008  Scientific and Technical (Gordon E. Sawyer Award)             NaN
#       Year                   Category  \
# 2721  1990  Special Achievement Award
# 2081  1995  Special Achievement Award
#
#                                         Additional Info
# 2721  Eric Brevig, Rob Bottin, Tim McGovern, Alex Funke
# 2081                                                NaN
#       Year                                   Category  \
# 1293  2001  Scientific and Technical (Special Awards)
# 519   2007  Scientific and Technical (Special Awards)
#
#                                         Additional Info
# 1293   first published by the ASC in 1930, the Ameri...
# 519                                                 NaN
#       Year        Category Additional Info
# 6226  1960  Acting (other)             NaN
#        Year                                Category Additional Info
# 10132  1927  Engineering Effects (archaic category)           Wings
# 10131  1927  Engineering Effects (archaic category)             NaN
#        Year                                        Category Additional Info
# 10134  1927  Unique and Artistic Picture (archaic category)         Sunrise

# %% [markdown]
# I will not how these can be cleaned up as there are too many categories to address within each of which there could be variations.
#
# Instead, for the next question, I will discuss (not demonstrate) it for only for the "Art Direction" category.
#
# ### 7.2.1.  The nominations for the Art Direction category have lengthy values for Additional Info. What information is useful and how do we extract it?
#
# First, let's look at a few rows for "Art Direction" category.

# %%
df[df["Category"] == "Art Direction"].head()
# Out:
#     Year       Category                                      Nominee  \
# 23  2010  Art Direction                          Alice in Wonderland
# 24  2010  Art Direction  Harry Potter and the Deathly Hallows Part 1
# 25  2010  Art Direction                                    Inception
# 26  2010  Art Direction                            The King's Speech
# 27  2010  Art Direction                                    True Grit
#
#                                       Additional Info Won? Unnamed: 5  \
# 23  Production Design: Robert Stromberg; Set Decor...  YES        NaN
# 24  Production Design: Stuart Craig; Set Decoratio...   NO        NaN
# 25  Production Design: Guy Hendrix Dyas; Set Decor...   NO        NaN
# 26  Production Design: Eve Stewart; Set Decoration...   NO        NaN
# 27  Production Design: Jess Gonchor; Set Decoratio...   NO        NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10
# 23        NaN        NaN        NaN        NaN         NaN
# 24        NaN        NaN        NaN        NaN         NaN
# 25        NaN        NaN        NaN        NaN         NaN
# 26        NaN        NaN        NaN        NaN         NaN
# 27        NaN        NaN        NaN        NaN         NaN

# %% [markdown]
# OK, now I will list all "Additional Info" values for "Art Direction" category.

# %%
for i, s in df[df["Category"] == "Art Direction"].iterrows():
    print(s["Additional Info"])
# Out:
# Production Design: Robert Stromberg; Set Decoration: Karen O'Hara
# Production Design: Stuart Craig; Set Decoration: Stephenie McMillan
# Production Design: Guy Hendrix Dyas; Set Decoration: Larry Dias and Doug Mowat
# Production Design: Eve Stewart; Set Decoration: Judy Farr
# Production Design: Jess Gonchor; Set Decoration: Nancy Haigh
# Production Design: Rick Carter and Robert Stromberg; Set Decoration: Kim Sinclair
# Production Design: Dave Warren and Anastasia Masaro; Set Decoration: Caroline Smith
# Production Design: John Myhre; Set Decoration: Gordon Sim
# Production Design: Sarah Greenwood; Set Decoration: Katie Spencer
# Production Design: Patrice Vermette; Set Decoration: Maggie Gray
# Art Direction: James J. Murakami; Set Decoration: Gary Fettis
# Art Direction: Donald Graham Burt; Set Decoration: Victor J. Zolfo
# Art Direction: Nathan Crowley; Set Decoration: Peter Lando
# Art Direction: Michael Carlin; Set Decoration: Rebecca Alleway
# Art Direction: Kristi Zea; Set Decoration: Debra Schutt
# Art Direction: Arthur Max; Set Decoration: Beth A. Rubino
# Art Direction: Sarah Greenwood; Set Decoration: Katie Spencer
# Art Direction: Dennis Gassner; Set Decoration: Anna Pinnock
# Art Direction: Dante Ferretti; Set Decoration: Francesca Lo Schiavo
# Art Direction: Jack Fisk; Set Decoration: Jim Erickson
# Art Direction: John Myhre; Set Decoration: Nancy Haigh
# Art Direction: Jeannine Oppewall; Set Decoration: Gretchen Rau and Leslie E. Rollins
# Art Direction: Eugenio Caballero; Set Decoration: Pilar Revuelta
# Art Direction: Rick Heinrichs; Set Decoration: Cheryl Carasik
# Art Direction: Nathan Crowley; Set Decoration: Julie Ochipinti
# Art Direction: Jim Bissell; Set Decoration: Jan Pascale
# Art Direction: Stuart Craig; Set Decoration: Stephenie McMillan
# Art Direction: Grant Major; Set Decoration: Dan Hennah and Simon Bright
# Art Direction: John Myhre; Set Decoration: Gretchen Rau
# Art Direction: Sarah Greenwood; Set Decoration: Katie Spencer
# Art Direction: Dante Ferretti; Set Decoration: Francesca Lo Schiavo
# Art Direction: Gemma Jackson; Set Decoration: Trisha Edwards
# Art Direction: Rick Heinrichs; Set Decoration: Cheryl Carasik
# Art Direction: Anthony Pratt; Set Decoration: Celia Bobak
# Art Direction: Aline Bonetto
# Art Direction: Ben Van Os; Set Decoration: Cecile Heideman
# Art Direction: Lilly Kilvert; Set Decoration: Gretchen Rau
# Art Direction: Grant Major; Set Decoration: Dan Hennah and Alan Lee
# Art Direction: William Sandell; Set Decoration: Robert Gould
# Art Direction: Jeannine Oppewall; Set Decoration: Leslie Pope
# Art Direction: John Myhre; Set Decoration: Gordon Sim
# Art Direction: Felipe Fernandez del Paso; Set Decoration: Hania Robledo
# Art Direction: Dante Ferretti; Set Decoration: Francesca Lo Schiavo
# Art Direction: Grant Major; Set Decoration: Dan Hennah and Alan Lee
# Art Direction: Dennis Gassner; Set Decoration: Nancy Haigh
# Art Direction: Aline Bonetto; Set Decoration: Marie-Laure Valla
# Art Direction: Stephen Altman; Set Decoration: Anna Pinnock
# Art Direction: Stuart Craig; Set Decoration: Stephenie McMillan
# Art Direction: Grant Major; Set Decoration: Dan Hennah
# Art Direction: Catherine Martin; Set Decoration: Brigitte Broch
# Tim Yip
# Art Direction: Michael Corenblith; Set Decoration: Merideth Boswell
# Art Direction: Arthur Max; Set Decoration: Crispian Sallis
# Art Direction: Martin Childs; Set Decoration: Jill Quertier
# Art Direction: Jean Rabasse; Set Decoration: Françoise Benoît-Fresco
# Art Direction: Luciana Arrighi; Set Decoration: Ian Whittaker
# Art Direction: David Gropman; Set Decoration: Beth Rubino
# Art Direction: Rick Heinrichs; Set Decoration: Peter Young
# Art Direction: Roy Walker; Set Decoration: Bruno Cesari
# Art Direction: Eve Stewart; Set Decoration: Eve Stewart, John Bush
# Art Direction: John Myhre; Set Decoration: Peter Howitt
# Art Direction: Jeannine Oppewall; Set Decoration: Jay Hart
# Art Direction: Tom Sanders; Set Decoration: Lisa Dean Kavanaugh
# Art Direction: Martin Childs; Set Decoration: Jill Quertier
# Art Direction: Eugenio Zanetti; Set Decoration: Cindy Carr
# Art Direction: Jan Roelfs; Set Decoration: Nancy Nye
# Art Direction: Dante Ferretti; Set Decoration: Francesca Lo Schiavo
# Art Direction: Jeannine Oppewall; Set Decoration: Jay R. Hart
# Art Direction: Bo Welch; Set Decoration: Cheryl Carasik
# Art Direction: Peter Lamont; Set Decoration: Michael Ford
# Art Direction: Bo Welch; Set Decoration: Cheryl Carasik
# Art Direction: Stuart Craig; Set Decoration: Stephenie McMillan
# Art Direction: Brian Morris; Set Decoration: Philippe Turlure
# Tim Harvey
# Art Direction: Catherine Martin; Set Decoration: Brigitte Broch
# Art Direction: Michael Corenblith; Set Decoration: Merideth Boswell
# Art Direction: Roger Ford; Set Decoration: Kerrie Brown
# Art Direction: Bo Welch; Set Decoration: Cheryl Carasik
# Eugenio Zanetti
# Tony Burrough
# Art Direction: Santo Loquasto; Set Decoration: Susan Bode
# Art Direction: Rick Carter; Set Decoration: Nancy Haigh
# Art Direction: Dante Ferretti; Set Decoration: Francesca Lo Schiavo
# Art Direction: Lilly Kilvert; Set Decoration: Dorree Cooper
# Art Direction: Ken Adam; Set Decoration: Carolyn Scott
# Art Direction: Ken Adam; Set Decoration: Marvin March
# Art Direction: Dante Ferretti; Set Decoration: Robert J. Franco
# Art Direction: Ben Van Os, Jan Roelfs
# Art Direction: Luciana Arrighi; Set Decoration: Ian Whittaker
# Art Direction: Allan Starski; Set Decoration: Ewa Braun
# Art Direction: Thomas Sanders; Set Decoration: Garrett Lewis
# Art Direction: Stuart Craig; Set Decoration: Chris A. Butler
# Art Direction: Luciana Arrighi; Set Decoration: Ian Whittaker
# Art Direction: Ferdinando Scarfiotti; Set Decoration: Linda DeScenna
# Art Direction: Henry Bumstead; Set Decoration: Janice Blackie-Goodine
# Art Direction: Dennis Gassner; Set Decoration: Nancy Haigh
# Art Direction: Dennis Gassner; Set Decoration: Nancy Haigh
# Art Direction: Mel Bourne; Set Decoration: Cindy Carr
# Art Direction: Norman Garwood; Set Decoration: Garrett Lewis
# Art Direction: Paul Sylbert; Set Decoration: Caryl Heller
# Art Direction: Ezio Frigerio; Set Decoration: Jacques Rouxel
# Art Direction: Jeffrey Beecroft; Set Decoration: Lisa Dean
# Art Direction: Richard Sylbert; Set Decoration: Rick Simpson
# Art Direction: Dean Tavoularis; Set Decoration: Gary Fettis
# Art Direction: Dante Ferretti; Set Decoration: Francesca Lo Schiavo
# Art Direction: Leslie Dilley; Set Decoration: Anne Kuljian
# Art Direction: Dante Ferretti; Set Decoration: Francesca Lo Schiavo
# Art Direction: Anton Furst; Set Decoration: Peter Young
# Art Direction: Bruno Rubeo; Set Decoration: Crispian Sallis
# Art Direction: Norman Garwood; Set Decoration: Garrett Lewis
# Art Direction: Albert Brenner; Set Decoration: Garrett Lewis
# Art Direction: Stuart Craig; Set Decoration: Gerard James
# Art Direction: Ida Random; Set Decoration: Linda DeScenna
# Art Direction: Dean Tavoularis; Set Decoration: Armin Ganz
# Art Direction: Elliot Scott; Set Decoration: Peter Howitt
# Art Direction: Norman Reynolds; Set Decoration: Harry Cordwell
# Art Direction: Anthony Pratt; Set Decoration: Joan Woollard
# Art Direction: Ferdinando Scarfiotti; Set Decoration: Bruno Cesari, Osvaldo Desideri
# Art Direction: Santo Loquasto; Set Decoration: Carol Joffe, Les Bloom, George DeTitta, Jr.
# Art Direction: Patrizia Von Brandenstein, William A. Elliott; Set Decoration: Hal Gausman
# Art Direction: Peter Lamont; Set Decoration: Crispian Sallis
# Art Direction: Boris Leven; Set Decoration: Karen A. O'Hara
# Art Direction: Stuart Wurtzel; Set Decoration: Carol Joffe
# Art Direction: Stuart Craig; Set Decoration: Jack Stephens
# Art Direction: Gianni Quaranta, Brian Ackland-Snow; Set Decoration: Brian Savegar, Elio Altamura
# Art Direction: Norman Garwood; Set Decoration: Maggie Gray
# Art Direction: J. Michael Riva, Robert W. Welch; Set Decoration: Linda DeScenna
# Art Direction: Stephen Grimes; Set Decoration: Josie MacAvin
# Art Direction: Yoshiro Muraki, Shinobu Muraki
# Art Direction: Stan Jolley; Set Decoration: John Anderson
# Art Direction: Patrizia Von Brandenstein; Set Decoration: Karel Cerny
# Art Direction: Richard Sylbert; Set Decoration: George Gaines, Les Bloom
# Art Direction: Angelo Graham, Mel Bourne, James J. Murakami, Speed Hopkins; Set Decoration: Bruce Weintraub
# Art Direction: John Box, Leslie Tomkins; Set Decoration: Hugh Scaife
# Art Direction: Albert Brenner; Set Decoration: Rick Simpson
# Anna Asp
# Art Direction: Norman Reynolds, Fred Hole, James Schoppe; Set Decoration: Michael Ford
# Art Direction: Geoffrey Kirkland, Richard J. Lawrence, W. Stewart Campbell, Peter Romero; Set Decoration: Pat Pending, George R. Nelson
# Art Direction: Polly Platt, Harold Michelson; Set Decoration: Tom Pedigo, Anthony Mondello
# Art Direction: Roy Walker, Leslie Tomkins; Set Decoration: Tessa Davies
# Art Direction: Dale Hennesy; Set Decoration: Marvin March
# Art Direction: Lawrence G. Paull, David L. Snyder; Set Decoration: Linda DeScenna
# Art Direction: Stuart Craig, Bob Laing; Set Decoration: Michael Seirton
# Art Direction: Franco Zeffirelli; Set Decoration: Gianni Quaranta
# Art Direction: Rodger Maus, Tim Hutchinson, William Craig Smith; Set Decoration: Harry Cordwell
# Art Direction: Assheton Gorton; Set Decoration: Ann Mollo
# Art Direction: Tambi Larsen; Set Decoration: Jim Berkey
# Art Direction: John Graysmark, Patrizia Von Brandenstein, Anthony Reading; Set Decoration: George de Titta, Sr., George de Titta, Jr., Peter Howitt
# Art Direction: Norman Reynolds, Leslie Dilley; Set Decoration: Michael Ford
# Art Direction: Richard Sylbert; Set Decoration: Michael Seirton
# Art Direction: John W. Corso; Set Decoration: John M. Dwyer
# Art Direction: Stuart Craig, Bob Cartwright; Set Decoration: Hugh Scaife
# Art Direction: Norman Reynolds, Leslie Dilley, Harry Lange, Alan Tomkins; Set Decoration: Michael Ford
# Yoshiro Muraki
# Art Direction: Pierre Guffroy, Jack Stephens
# Art Direction: Michael Seymour, Les Dilley, Roger Christian; Set Decoration: Ian Whittaker
# Art Direction: Philip Rosenberg, Tony Walton; Set Decoration: Edward Stewart, Gary Brink
# Art Direction: Dean Tavoularis, Angelo Graham; Set Decoration: George R. Nelson
# Art Direction: George Jenkins; Set Decoration: Arthur Jeph Parker
# Art Direction: Harold Michelson, Joe Jennings, Leon Harris, John Vallone; Set Decoration: Linda DeScenna
# Art Direction: Dean Tavoularis, Angelo Graham; Set Decoration: George R. Nelson, Bruce Kay
# Art Direction: Albert Brenner; Set Decoration: Marvin March
# Art Direction: Paul Sylbert, Edwin O'Donovan; Set Decoration: George Gaines
# Art Direction: Mel Bourne; Set Decoration: Daniel Robert
# Art Direction: Tony Walton, Philip Rosenberg; Set Decoration: Edward Stewart, Robert Drumheller
# Art Direction: George C. Webb; Set Decoration: Mickey S. Michaels
# Art Direction: Joe Alves, Dan Lomino; Set Decoration: Phil Abramson
# Art Direction: Ken Adam, Peter Lamont; Set Decoration: Hugh Scaife
# Art Direction: John Barry, Norman Reynolds, Leslie Dilley; Set Decoration: Roger Christian
# Art Direction: Albert Brenner; Set Decoration: Marvin March
# Art Direction: George Jenkins; Set Decoration: George Gaines
# Art Direction: Elliot Scott, Norman Reynolds; Set Decoration: Peter Howitt
# Art Direction: Gene Callahan, Jack Collis; Set Decoration: Jerry Wunderlich
# Art Direction: Dale Hennesy; Set Decoration: Robert de Vestel
# Art Direction: Robert F. Boyle; Set Decoration: Arthur Jeph Parker
# Art Direction: Ken Adam, Roy Walker; Set Decoration: Vernon Dixon
# Art Direction: Edward Carfagno; Set Decoration: Frank McKelvy
# Art Direction: Alexander Trauner, Tony Inglis; Set Decoration: Peter James
# Art Direction: Richard Sylbert, W. Stewart Campbell; Set Decoration: George Gaines
# Art Direction: Albert Brenner; Set Decoration: Marvin March
# Art Direction: Richard Sylbert, W. Stewart Campbell; Set Decoration: Ruby Levitt
# Art Direction: Alexander Golitzen, E. Preston Ames; Set Decoration: Frank McKelvy
# Art Direction: Dean Tavoularis, Angelo Graham; Set Decoration: George R. Nelson
# Art Direction: Peter Ellenshaw, John B. Mansbridge, Walter Tyler, Al Roelofs; Set Decoration: Hal Gausman
# Art Direction: William Creber, Ward Preston; Set Decoration: Raphael Bretton
# Art Direction: Lorenzo Mongiardino, Gianni Quaranta; Set Decoration: Carmelo Patrono
# Art Direction: Bill Malley; Set Decoration: Jerry Wunderlich
# Art Direction: Henry Bumstead; Set Decoration: James Payne
# Art Direction: Philip Jefferies; Set Decoration: Robert de Vestel
# Art Direction: Stephen Grimes; Set Decoration: William Kiernan
# Art Direction: Rolf Zehetbauer, Jurgen Kiebach; Set Decoration: Herbert Strabel
# Art Direction: Carl Anderson; Set Decoration: Reg Allen
# Art Direction: William Creber; Set Decoration: Raphael Bretton
# Art Direction: John Box, Gil Parrondo, Robert W. Laing
# Art Direction: Geoffrey Drake, Don Ashton, John Graysmark, William Hutchinson; Set Decoration: Peter James
# Art Direction: Boris Leven, William Tuntke; Set Decoration: Ruby Levitt
# Art Direction: John B. Mansbridge, Peter Ellenshaw; Set Decoration: Emile Kuri, Hal Gausman
# Art Direction: Robert Boyle, Michael Stringer; Set Decoration: Peter Lamont
# Art Direction: Terence Marsh, Robert Cartwright; Set Decoration: Peter Howitt
# Art Direction: John Box, Ernest Archer, Jack Maxsted, Gil Parrondo; Set Decoration: Vernon Dixon
# Art Direction: Alexander Golitzen, E. Preston Ames; Set Decoration: Jack D. Moore, Mickey S. Michaels
# Art Direction: Tambi Larsen; Set Decoration: Darrell Silvera
# Art Direction: Urie McCleary, Gil Parrondo; Set Decoration: Antonio Mateos, Pierre-Louis Thevenet
# Art Direction: Terry Marsh, Bob Cartwright; Set Decoration: Pamela Cornell
# Art Direction: Jack Martin Smith, Yoshiro Muraki, Richard Day, Taizoh Kawashima; Set Decoration: Walter M. Scott, Norman Rockett, Carl Biddiscombe
# Art Direction: Maurice Carter, Lionel Couch; Set Decoration: Patrick McLoughlin
# Art Direction: Robert Boyle, George B. Chan; Set Decoration: Edward Boyle, Carl Biddiscombe
# Art Direction: John DeCuir, Jack Martin Smith, Herman Blumenthal; Set Decoration: Walter M. Scott, George Hopkins, Raphael Bretton
# Art Direction: Alexander Golitzen, George C. Webb; Set Decoration: Jack D. Moore
# Art Direction: Harry Horner; Set Decoration: Frank McKelvy
# Art Direction: John Box, Terence Marsh; Set Decoration: Vernon Dixon, Ken Muggleston
# Art Direction: George W. Davis, Edward Carfagno
# Art Direction: Boris Leven; Set Decoration: Walter M. Scott, Howard Bristol
# Art Direction: Tony Masters, Harry Lange, Ernie Archer
# Art Direction: Mikhail Bogdanov, Gennady Myasnikov; Set Decoration: G. Koshelev, V. Uvarov
# Art Direction: John Truscott, Edward Carrere; Set Decoration: John W. Brown
# Art Direction: Mario Chiari, Jack Martin Smith, Ed Graves; Set Decoration: Walter M. Scott, Stuart A. Reiss
# Art Direction: Robert Clatworthy; Set Decoration: Frank Tuttle
# Art Direction: Renzo Mongiardino, John DeCuir, Elven Webb, Giuseppe Mariani; Set Decoration: Dario Simoni, Luigi Gervasi
# Art Direction: Alexander Golitzen, George C. Webb; Set Decoration: Howard Bristol
# Art Direction: Robert Luthardt; Set Decoration: Edward G. Boyle
# Luigi Scaccianoce
# Art Direction: Willy Holt; Set Decoration: Marc Frederix, Pierre Guffroy
# Art Direction: George W. Davis, Paul Groesse; Set Decoration: Henry Grace, Hugh Hunt
# Art Direction: Richard Sylbert; Set Decoration: George James Hopkins
# Art Direction: Jack Martin Smith, Dale Hennesy; Set Decoration: Walter M. Scott, Stuart A. Reiss
# Art Direction: Alexander Golitzen, George C. Webb; Set Decoration: John McCarthy, John Austin
# Piero Gherardi
# Art Direction: Hal Pereira, Arthur Lonergan; Set Decoration: Robert Benton, James Payne
# Art Direction: Boris Leven; Set Decoration: Walter M. Scott, John Sturtevant, William Kiernan
# Art Direction: Robert Emmet Smith; Set Decoration: Frank Tuttle
# Art Direction: George W. Davis, Urie McCleary; Set Decoration: Henry Grace, Charles S. Thompson
# Art Direction: Robert Clatworthy; Set Decoration: Joseph Kish
# Art Direction: Hal Pereira, Jack Poplin; Set Decoration: Robert Benton, Joseph Kish
# Art Direction: Hal Pereira, Tambi Larsen, Edward Marshall; Set Decoration: Josie MacAvin
# Art Direction: John DeCuir, Jack Martin Smith; Set Decoration: Dario Simoni
# Art Direction: John Box, Terry Marsh; Set Decoration: Dario Simoni
# Art Direction: Richard Day, William Creber, David Hall; Set Decoration: Ray Moyer, Fred MacLean, Norman Rockett
# Art Direction: Robert Clatworthy; Set Decoration: George James Hopkins
# Art Direction: Boris Leven; Set Decoration: Walter M. Scott, Ruby Levitt
# Art Direction: George W. Davis, Hans Peters, Elliot Scott; Set Decoration: Henry Grace, Robert R. Benton
# Art Direction: William Glasgow; Set Decoration: Raphael Bretton
# Stephen Grimes
# Art Direction: Cary Odell; Set Decoration: Edward G. Boyle
# Vassilis Fotopoulos
# Art Direction: John Bryan, Maurice Carter; Set Decoration: Patrick McLoughlin, Robert Cartwright
# Art Direction: Carroll Clark, William H. Tuntke; Set Decoration: Emile Kuri, Hal Gausman
# Art Direction: Gene Allen, Cecil Beaton; Set Decoration: George James Hopkins
# Art Direction: George W. Davis, Preston Ames; Set Decoration: Henry Grace, Hugh Hunt
# Art Direction: Jack Martin Smith, Ted Haworth; Set Decoration: Walter M. Scott, Stuart A. Reiss
# Gene Callahan
# Piero Gherardi
# Art Direction: Hal Pereira, Tambi Larsen; Set Decoration: Sam Comer, Robert Benton
# Art Direction: Hal Pereira, Roland Anderson; Set Decoration: Sam Comer, Grace Gregory
# Art Direction: George W. Davis, Paul Groesse; Set Decoration: Henry Grace, Hugh Hunt
# Art Direction: Lyle Wheeler; Set Decoration: Gene Callahan
# Art Direction: John DeCuir, Jack Martin Smith, Hilyard Brown, Herman Blumenthal, Elven Webb, Maurice Pelling, Boris Juraga; Set Decoration: Walter M. Scott, Paul S. Fox, Ray Moyer
# Art Direction: Hal Pereira, Roland Anderson; Set Decoration: Sam Comer, James Payne
# Art Direction: George W. Davis, William Ferrari, Addison Hehr; Set Decoration: Henry Grace, Don Greenwood, Jr., Jack Mills
# Art Direction: Ralph Brinton, Ted Marshall, Jocelyn Herbert; Set Decoration: Josie MacAvin
# Art Direction: Joseph Wright; Set Decoration: George James Hopkins
# Art Direction: Ted Haworth, Leon Barsacq, Vincent Korda; Set Decoration: Gabriel Bechir
# Art Direction: George W. Davis, Edward Carfagno; Set Decoration: Henry Grace, Dick Pefferle
# Art Direction: Hal Pereira, Roland Anderson; Set Decoration: Sam Comer, Frank R. McKelvy
# Art Direction: Alexander Golitzen, Henry Bumstead; Set Decoration: Oliver Emert
# Art Direction: John Box, John Stoll; Set Decoration: Dario Simoni
# Art Direction: Paul Groesse; Set Decoration: George James Hopkins
# Art Direction: George W. Davis, J. McMillan Johnson; Set Decoration: Henry Grace, Hugh Hunt
# Art Direction: Alexander Golitzen, Robert Clatworthy; Set Decoration: George Milo
# Art Direction: George W. Davis, Edward Carfagno; Set Decoration: Henry Grace, Dick Pefferle
# Art Direction: Carroll Clark; Set Decoration: Emile Kuri, Hal Gausman
# Art Direction: Fernando Carrere; Set Decoration: Edward G. Boyle
# Art Direction: Harry Horner; Set Decoration: Gene Callahan
# Art Direction: Rudolph Sternad; Set Decoration: George Milo
# Piero Gherardi
# Art Direction: Hal Pereira, Roland Anderson; Set Decoration: Sam Comer, Ray Moyer
# Art Direction: Veniero Colasanti, John Moore
# Art Direction: Alexander Golitzen, Joseph Wright; Set Decoration: Howard Bristol
# Art Direction: Hal Pereira, Walter Tyler; Set Decoration: Sam Comer, Arthur Krams
# Art Direction: Boris Leven; Set Decoration: Victor A. Gangelin
# Art Direction: Alexander Trauner; Set Decoration: Edward G. Boyle
# Art Direction: Joseph McMillan Johnson, Kenneth A. Reid; Set Decoration: Ross Dowd
# Art Direction: Joseph Hurley, Robert Clatworthy; Set Decoration: George Milo
# Art Direction: Tom Morahan; Set Decoration: Lionel Couch
# Art Direction: Hal Pereira, Walter Tyler; Set Decoration: Sam Comer, Arthur Krams
# Art Direction: George W. Davis, Addison Hehr; Set Decoration: Henry Grace, Hugh Hunt, Otto Siegel
# Art Direction: Hal Pereira, Roland Anderson; Set Decoration: Sam Comer, Arrigo Breschi
# Art Direction: Ted Haworth; Set Decoration: William Kiernan
# Art Direction: Alexander Golitzen, Eric Orbom; Set Decoration: Russell A. Gausman, Julia Heron
# Art Direction: Edward Carrere; Set Decoration: George James Hopkins
# Art Direction: Hal Pereira, Walter Tyler; Set Decoration: Sam Comer, Arthur Krams
# Art Direction: Lyle R. Wheeler, George W. Davis; Set Decoration: Walter M. Scott, Stuart A. Reiss
# Art Direction: Carl Anderson; Set Decoration: William Kiernan
# Art Direction: Ted Haworth; Set Decoration: Edward G. Boyle
# Art Direction: Oliver Messel, William Kellner; Set Decoration: Scot Slimon
# Art Direction: William A. Horning, Edward Carfagno; Set Decoration: Hugh Hunt
# Art Direction: John DeCuir; Set Decoration: Julia Heron
# Art Direction: Lyle R. Wheeler, Franz Bachelin, Herman A. Blumenthal; Set Decoration: Walter M. Scott, Joseph Kish
# Art Direction: William A. Horning, Robert Boyle, Merrill Pye; Set Decoration: Henry Grace, Frank McKelvy
# Art Direction: Richard H. Riedel; Set Decoration: Russell A. Gausman, Ruby R. Levitt
# Art Direction: Malcolm Bert; Set Decoration: George James Hopkins
# Art Direction: Cary Odell; Set Decoration: Louis Diage
# Art Direction: Lyle R. Wheeler, John DeCuir; Set Decoration: Walter M. Scott, Paul S. Fox
# Art Direction: William A. Horning, Preston Ames; Set Decoration: Henry Grace, Keogh Gleason
# Art Direction: Hal Pereira, Henry Bumstead; Set Decoration: Sam Comer, Frank McKelvy
# Art Direction: Hal Pereira, George W. Davis; Set Decoration: Sam Comer, Ray Moyer
# Art Direction: William A. Horning, Gene Allen; Set Decoration: Edwin B. Willis, Richard Pefferle
# Art Direction: Walter Holscher; Set Decoration: William Kiernan, Louis Diage
# Art Direction: William A. Horning, Urie McCleary; Set Decoration: Edwin B. Willis, Hugh Hunt
# Art Direction: Ted Haworth; Set Decoration: Robert Priestley
# Takashi Matsuyama
# Art Direction: Hal Pereira, A. Earl Hedrick; Set Decoration: Samuel M. Comer, Frank R. McKelvy
# Art Direction: Ross Bellah; Set Decoration: William R. Kiernan, Louis Diage
# Art Direction: Cedric Gibbons, Malcolm F. Brown; Set Decoration: Edwin B. Willis, F. Keogh Gleason
# Art Direction: Lyle R. Wheeler, Jack Martin Smith; Set Decoration: Walter M. Scott, Stuart A. Reiss
# Art Direction: James W. Sullivan, Ken Adam; Set Decoration: Ross J. Dowd
# Art Direction: Boris Leven; Set Decoration: Ralph S. Hurst
# Art Direction: Lyle R. Wheeler, John DeCuir; Set Decoration: Walter M. Scott, Paul S. Fox
# Art Direction: Cedric Gibbons, Hans Peters, Preston Ames; Set Decoration: Edwin B. Willis, F. Keogh Gleason
# Art Direction: Hal Pereira, Walter H. Tyler, Albert Nozaki; Set Decoration: Samuel M. Comer, Ray Moyer
# Art Direction: Cedric Gibbons, Randall Duell; Set Decoration: Edwin B. Willis, Henry Grace
# Art Direction: Cedric Gibbons, Malcolm Brown; Set Decoration: Edwin B. Willis, Hugh B. Hunt
# Art Direction: Joseph C. Wright; Set Decoration: Darrell Silvera
# Art Direction: Edward S. Haworth, Walter Simonds; Set Decoration: Robert Priestley
# Art Direction: Hal Pereira, Tambi Larsen; Set Decoration: Sam Comer, Arthur Krams
# Art Direction: Lyle Wheeler, John DeCuir; Set Decoration: Walter M. Scott, Paul S. Fox
# Art Direction: Oliver Smith, Joseph C. Wright; Set Decoration: Howard Bristol
# Art Direction: Lyle Wheeler, George W. Davis; Set Decoration: Walter M. Scott, Jack Stubbs
# Art Direction: William Flannery, Jo Mielziner; Set Decoration: Robert Priestley
# Art Direction: Hal Pereira, Joseph McMillan Johnson; Set Decoration: Sam Comer, Arthur Krams
# Art Direction: Hal Pereira, Roland Anderson; Set Decoration: Sam Comer, Grace Gregory
# Art Direction: Cedric Gibbons, Edward Carfagno; Set Decoration: Edwin B. Willis, Emile Kuri
# Max Ophuls
# Richard Day
# Art Direction: Hal Pereira, Walter Tyler; Set Decoration: Sam Comer, Ray Moyer
# Art Direction: Cedric Gibbons, Preston Ames; Set Decoration: Edwin B. Willis, Keogh Gleason
# Art Direction: Lyle Wheeler, Leland Fuller; Set Decoration: Walter M. Scott, Paul S. Fox
# Art Direction: Hal Pereira, Roland Anderson; Set Decoration: Sam Comer, Ray Moyer
# Art Direction: Malcolm Bert, Gene Allen, Irene Sharaff; Set Decoration: George James Hopkins
# Art Direction: John Meehan; Set Decoration: Emile Kuri
# Art Direction: Cedric Gibbons, Edward Carfagno; Set Decoration: Edwin B. Willis, Hugh Hunt
# Art Direction: Fritz Maurischat, Paul Markwitz
# Art Direction: Lyle Wheeler, Leland Fuller; Set Decoration: Paul S. Fox
# Art Direction: Hal Pereira, Walter Tyler
# Art Direction: Lyle Wheeler, Maurice Ransford; Set Decoration: Stuart Reiss
# Art Direction: Alfred Junge, Hans Peters; Set Decoration: John Jarvis
# Art Direction: Cedric Gibbons, Paul Groesse; Set Decoration: Edwin B. Willis, Arthur Krams
# Art Direction: Lyle Wheeler, George W. Davis; Set Decoration: Walter M. Scott, Paul S. Fox
# Art Direction: Cedric Gibbons, Preston Ames, Edward Carfagno, Gabriel Scognamillo; Set Decoration: Edwin B. Willis, Keogh Gleason, Arthur Krams, Jack D. Moore
# Art Direction: Cedric Gibbons, Urie McCleary; Set Decoration: Edwin B. Willis, Jack D. Moore
# Art Direction: Cedric Gibbons, Edward Carfagno; Set Decoration: Edwin B. Willis, Keogh Gleason
# Art Direction: Hal Pereira, Roland Anderson; Set Decoration: Emile Kuri
# Art Direction: Lyle Wheeler, John DeCuir; Set Decoration: Walter M. Scott
# Art Direction: Matsuyama; Set Decoration: H. Motsumoto
# Art Direction: Lyle Wheeler, Leland Fuller; Set Decoration: Thomas Little, Claude Carpenter
# Art Direction: Richard Day, Clave; Set Decoration: Howard Bristol
# Art Direction: Cedric Gibbons, Paul Groesse; Set Decoration: Edwin B. Willis, Arthur Krams
# Art Direction: Paul Sheriff; Set Decoration: Marcel Vertes
# Art Direction: Frank Hotaling; Set Decoration: John McCarthy, Jr., Charles Thompson
# Art Direction: Lyle Wheeler, John DeCuir; Set Decoration: Thomas Little, Paul S. Fox
# Art Direction: Lyle Wheeler, Leland Fuller; Set Decoration: Thomas Little, Fred J. Rode
# Art Direction: Lyle Wheeler, John DeCuir; Set Decoration: Thomas Little, Paul S. Fox
# D'Eaubonne
# Art Direction: Richard Day; Set Decoration: George James Hopkins
# Art Direction: Cedric Gibbons, Paul Groesse; Set Decoration: Edwin B. Willis, Jack D. Moore
# Art Direction: Cedric Gibbons, Preston Ames; Set Decoration: Edwin B. Willis, Keogh Gleason
# Art Direction: Lyle Wheeler, George Davis; Set Decoration: Thomas Little, Paul S. Fox
# Art Direction: Lyle Wheeler, Leland Fuller; Musical Settings: Joseph C. Wright; Set Decoration: Thomas Little, Walter M. Scott
# Art Direction: William A. Horning, Cedric Gibbons, Edward Carfagno; Set Decoration: Hugh Hunt
# Hein Heckroth
# Art Direction: Lyle Wheeler, George W. Davis; Set Decoration: Thomas Little, Walter M. Scott
# Art Direction: Cedric Gibbons, Hans Peters; Set Decoration: Edwin B. Willis, Hugh Hunt
# Art Direction: Hans Dreier, John Meehan; Set Decoration: Sam Comer, Ray Moyer
# Art Direction: Cedric Gibbons, Paul Groesse; Set Decoration: Edwin B. Willis, Richard A. Pefferle
# Art Direction: Ernst Fegte; Set Decoration: George Sawley
# Art Direction: Hans Dreier, Walter Tyler; Set Decoration: Sam Comer, Ray Moyer
# Art Direction: Lyle Wheeler, Joseph C. Wright; Set Decoration: Thomas Little, Paul S. Fox
# Art Direction: Harry Horner, John Meehan; Set Decoration: Emile Kuri
# Art Direction: Cedric Gibbons, Jack Martin Smith; Set Decoration: Edwin B. Willis, Richard A. Pefferle
# Art Direction: Edward Carrere; Set Decoration: Lyle Reifsnider
# Art Direction: Cedric Gibbons, Paul Groesse; Set Decoration: Edwin B. Willis, Jack D. Moore
# Art Direction: Jim Morahan, William Kellner, Michael Relph
# Art Direction: Roger K. Furse; Set Decoration: Carmen Dillon
# Art Direction: Robert Haas; Set Decoration: William Wallace
# Art Direction: Richard Day; Set Decoration: Edwin Casey Roberts, Joseph Kish
# Art Direction: Hein Heckroth; Set Decoration: Arthur Lawson
# Art Direction: Lyle Wheeler, Maurice Ransford; Set Decoration: Thomas Little, Paul S. Fox
# Art Direction: John Bryan; Set Decoration: Wilfred Shingleton
# Art Direction: Alfred Junge; Set Decoration: Alfred Junge
# Art Direction: Robert M. Haas; Set Decoration: George James Hopkins
# Art Direction: Lyle Wheeler, William Darling; Interior Decoration: Thomas Little, Frank E. Hughes
# Art Direction: Hans Dreier, Walter Tyler; Interior Decoration: Sam Comer, Ray Moyer
# Art Direction: Richard Day, Nathan Juran; Interior Decoration: Thomas Little, Paul S. Fox
# John Bryan
# Art Direction: Paul Sheriff, Carmen Dillon
# Art Direction: Cedric Gibbons, Paul Groesse; Interior Decoration: Edwin B. Willis
# Art Direction: Wiard Ihnen; Interior Decoration: A. Roland Fields
# Art Direction: Albert S. D'Agostino, Jack Okey; Interior Decoration: Darrell Silvera, Claude Carpenter
# Art Direction: James Basevi, William Darling; Interior Decoration: Thomas Little, Frank E. Hughes
# Art Direction: Hans Dreier, Roland Anderson; Interior Decoration: Sam Comer, Ray Moyer
# Art Direction: Cedric Gibbons, Hans Peters; Interior Decoration: Edwin B. Willis, Hugh Hunt, John Bonar
# Art Direction: Hans Dreier, Ernst Fegte; Interior Decoration: Sam Comer
# Art Direction: Lyle Wheeler, Maurice Ransford; Interior Decoration: Thomas Little
# Art Direction: Cedric Gibbons, Urie McCleary; Interior Decoration: Edwin B. Willis, Mildred Griffiths
# Art Direction: Ted Smith; Interior Decoration: Jack McConaghy
# Art Direction: Stephen Goosson, Rudolph Sternad; Interior Decoration: Frank Tuttle
# Art Direction: Lionel Banks, Walter Holscher; Interior Decoration: Joseph Kish
# Art Direction: John J. Hughes; Interior Decoration: Fred MacLean
# Art Direction: Perry Ferguson; Interior Decoration: Julia Heron
# Art Direction: Cedric Gibbons, William Ferrari; Interior Decoration: Edwin B. Willis, Paul Huldschinsky
# Art Direction: Lyle Wheeler, Leland Fuller; Interior Decoration: Thomas Little
# Art Direction: Hans Dreier, Robert Usher; Interior Decoration: Sam Comer
# Art Direction: Mark-Lee Kirk; Interior Decoration: Victor A. Gangelin
# nan
# Art Direction: Albert S. D'Agostino, Carroll Clark; Interior Decoration: Darrell Silvera, Claude Carpenter
# Art Direction: John B. Goodman, Alexander Golitzen; Interior Decoration: Russell A. Gausman, Ira S. Webb
# Art Direction: Lionel Banks, Cary Odell; Interior Decoration: Fay Babcock
# Art Direction: Charles Novi; Interior Decoration: Jack McConaghy
# Art Direction: Cedric Gibbons, Daniel B. Cathcart; Interior Decoration: Edwin B. Willis, Richard Pefferle
# Art Direction: Hans Dreier, Raoul Pene du Bois; Interior Decoration: Ray Moyer
# Art Direction: Ernst Fegte; Interior Decoration: Howard Bristol
# Art Direction: Wiard Ihnen; Interior Decoration: Thomas Little
# Art Direction: Hans Dreier, Ernst Fegte; Interior Decoration: Bertram Granger
# Art Direction: Albert S. D'Agostino, Carroll Clark; Interior Decoration: Darrell Silvera, Harley Miller
# Art Direction: Cedric Gibbons, Paul Groesse; Interior Decoration: Edwin B. Willis, Hugh Hunt
# Art Direction: Carl Weyl; Interior Decoration: George J. Hopkins
# Art Direction: Perry Ferguson; Interior Decoration: Howard Bristol
# Art Direction: James Basevi, William Darling; Interior Decoration: Thomas Little
# Art Direction: Hans Dreier, Haldane Douglas; Interior Decoration: Bertram Granger
# Art Direction: James Basevi, Joseph C. Wright; Interior Decoration: Thomas Little
# Art Direction: John B. Goodman, Alexander Golitzen; Interior Decoration: Russell A. Gausman, Ira S. Webb
# Art Direction: John Hughes, Lt. John Koenig; Interior Decoration: George J. Hopkins
# Art Direction: Cedric Gibbons, Daniel Cathcart; Interior Decoration: Edwin B. Willis, Jacques Mersereau
# Art Direction: Max Parker, Mark-Lee Kirk; Interior Decoration: Casey Roberts
# Art Direction: Albert S. D'Agostino; Interior Decoration: Darrell Silvera, Al Fields
# Art Direction: Perry Ferguson; Interior Decoration: Howard Bristol
# Art Direction: Cedric Gibbons, Randall Duell; Interior Decoration: Edwin B. Willis, Jack Moore
# Art Direction: Boris Leven; Interior Decoration: Boris Leven
# Art Direction: Ralph Berger; Interior Decoration: Emile Kuri
# Art Direction: Jack Otterson, John B. Goodman; Interior Decoration: Russell A. Gausman, Edward R. Robinson
# Art Direction: Hans Dreier, Roland Anderson; Interior Decoration: Sam Comer
# Art Direction: Lionel Banks, Rudolph Sternad; Interior Decoration: Fay Babcock
# Art Direction: Richard Day, Joseph Wright; Interior Decoration: Thomas Little
# Art Direction: Jack Otterson, Alexander Golitzen; Interior Decoration: Russell A. Gausman, Ira S. Webb
# Art Direction: Ted Smith; Interior Decoration: Casey Roberts
# Art Direction: Vincent Korda; Interior Decoration: Julia Heron
# Art Direction: Richard Day, Joseph Wright; Interior Decoration: Thomas Little
# Art Direction: Hans Dreier, Roland Anderson; Interior Decoration: George Sawley
# Art Direction: Perry Ferguson, Van Nest Polglase; Interior Decoration: Al Fields, Darrell Silvera
# Art Direction: Martin Obzina, Jack Otterson; Interior Decoration: Russell A. Gausman
# Art Direction: Hans Dreier, Robert Usher; Interior Decoration: Sam Comer
# Art Direction: Richard Day, Nathan Juran; Interior Decoration: Thomas Little
# Art Direction: Lionel Banks; Interior Decoration: George Montgomery
# Art Direction: Stephen Goosson; Interior Decoration: Howard Bristol
# Art Direction: John Hughes; Interior Decoration: Fred MacLean
# nan
# Art Direction: John DuCasse Schulze; Interior Decoration: Edward G. Boyle
# Art Direction: Alexander Golitzen; Interior Decoration: Richard Irvine
# Art Direction: Vincent Korda; Interior Decoration: Julia Heron
# Art Direction: Cedric Gibbons, Randall Duell; Interior Decoration: Edwin B. Willis
# Art Direction: Richard Day, Joseph C. Wright; Interior Decoration: Thomas Little
# Art Direction: Cedric Gibbons, Urie McCleary; Interior Decoration: Edwin B. Willis
# Art Direction: Raoul Pene du Bois; Interior Decoration: Stephen A. Seymour
# Hans Dreier, Robert Usher
# Lionel Banks, Robert Peterson
# John Otterson
# John Victor Mackay
# Alexander Golitzen
# Richard Day, Joseph C. Wright
# Van Nest Polglase, Mark-Lee Kirk
# John DuCasse Schulze
# Lewis J. Rachmil
# Cedric Gibbons, Paul Groesse
# Lyle Wheeler
# Anton Grot
# James Basevi
# Cedric Gibbons, John S. Detlie
# Richard Day, Joseph C. Wright
# Hans Dreier, Roland Anderson
# Vincent Korda
# Hans Dreier, Robert Odell
# Charles D. Hall
# Jack Otterson, Martin Obzina
# Lyle Wheeler
# Van Nest Polglase, Al Herman
# John Victor Mackay
# Lionel Banks
# Anton Grot
# William Darling, George Dudley
# Alexander Toluboff
# Cedric Gibbons, William A. Horning
# James Basevi
# Carl J. Weyl
# Lyle Wheeler
# Bernard Herzbrun, Boris Leven
# Alexander Toluboff
# Van Nest Polglase
# Richard Day
# Stephen Goosson, Lionel Banks
# Hans Dreier, John Goodman
# Jack Otterson
# Cedric Gibbons
# Charles D. Hall
# Cedric Gibbons, William Horning
# Carroll Clark
# Richard Day
# Wiard Ihnen
# Anton Grot
# Stephen Goosson
# John Victor Mackay
# Lyle Wheeler
# Hans Dreier, Roland Anderson
# Alexander Toluboff
# William S. Darling, David Hall
# Jack Otterson
# Anton Grot
# Richard Day
# Cedric Gibbons, Eddie Imazu, Edwin B. Willis
# William S. Darling
# Albert S. D'Agostino, Jack Otterson
# Cedric Gibbons, Fredric Hope, Edwin B. Willis
# Perry Ferguson
# Richard Day
# Hans Dreier, Roland Anderson [came in 3rd]
# Van Nest Polglase, Carroll Clark [came in 2nd]
# Richard Day [came in 3rd]
# Van Nest Polglase, Carroll Clark [came in 2nd]
# Cedric Gibbons, Fredric Hope
# William S. Darling
# Hans Dreier, Roland Anderson [came in 2nd]
# Cedric Gibbons [came in 3rd]
# Lazare Meerson
# Richard Day
# Gordon Wiles
# Max Rée
# Stephen Goosson, Ralph Hammeras
# Hans Dreier
# Anton Grot
# Richard Day
# (William Cameron Menzies)
# Herman Rosse
# (Hans Dreier)
# (Jack Okey)
# (Hans Dreier)
# The Patriot
# The Bridge of San Luis Rey
# Dynamite
# Alibi; and The Awakening
# Street Angel
# Sunrise
# The Dove; and Tempest
# 7th Heaven

# %% [markdown]
# The values are in irregular pattern. Some contain only names (e.g. "William S. Darling, David Hall") whereas others contain field name and name of nominee (e.g. "Production Design: Robert Stromberg; Set Decoration: Karen O'Hara
# "). I will demonstrate parsing one value of the latter case.

# %%
add_info_ad = df[df["Category"] == "Art Direction"]["Additional Info"].iloc[0]

add_info_ad_split = re.split(";\ ", add_info_ad)

for i in add_info_ad_split:
    print(re.split(":\ ", i))
# Out:
# ['Production Design', 'Robert Stromberg']
# ['Set Decoration', "Karen O'Hara"]

# %% [markdown]
# ## Many values in Additional Info don't contain the character name the actor or actress played. Should we toss out character name altogether as we expand our data? What tradeoffs do we make by doing so?
#
# I will first check if character names are missing in any rows for "Additional Info" column.

# %%
import re

# 1. get acting-related rows from original dataset
df_act = df[(df["Category"].str.contains("act", case=False)) & \
         (~df["Category"].str.contains("action", case=False))]


# 2. check if any rows are missing character names

add_info_atypical = []
add_info_null = []

# get values in "Additional Info" column for acting-related rows
for i, s in df_act.iterrows():
    if "act" in s["Category"].lower() and \
    "action" not in s["Category"].lower():
        sval = s["Additional Info"]
        
        # show "Additional Info" values if appearing atypical
        if s.notnull()["Additional Info"]:
            sval_split = list(filter(None, re.split(" {'", re.sub("'}", "", sval))))
            if len(sval_split) != 2:
                add_info_atypical.append(sval)
                
display(add_info_atypical)
# Out:
# ["The Big Pond {'Pierre Mirande'}; and The Love Parade {'Count Alfred Renard'}",
#  "Bulldog Drummond {'Hugh 'Bulldog' Drummond'}; and Condemned {'Michel'}",
#  "Anna Christie {'Anna Christie'}; and Romance {'Madame Rita Cavallini'}",
#  "The Noose {'Nickie Elkins'}; and The Patent Leather Kid {'The Patent Leather Kid'}",
#  "The Last Command {'General Dolgorucki [Grand Duke Sergius Alexander]'}; and The Way of All Flesh {'August Schilling'}",
#  "7th Heaven {'Diane'}; Street Angel {'Angela'}; and Sunrise {'The Wife'}"]

# %% [markdown]
# There were rows with atypical values, but none missed either movie title or character name.
#
# Next, I will check the rows where "Additional Info" has null values.

# %%
display(df_act[df_act["Additional Info"].isna()].drop(labels=['Won?', 
                                              'Unnamed: 5',
                                              'Unnamed: 6',
                                              'Unnamed: 7',
                                              'Unnamed: 8',
                                              'Unnamed: 9',
                                              'Unnamed: 10'],
                                             axis=1))
# Out:
#        Year               Category  \
# 6226   1960         Acting (other)
# 6966   1954         Acting (other)
# 6967   1954         Acting (other)
# 7623   1949         Acting (other)
# 7745   1948         Acting (other)
# 7860   1947         Acting (other)
# 7974   1946         Acting (other)
# 7975   1946         Acting (other)
# 8089   1945         Acting (other)
# 8252   1944         Acting (other)
# 9165   1939         Acting (other)
# 9318   1938         Acting (other)
# 9795   1934         Acting (other)
# 10100  1927  Actor -- Leading Role
# 10104  1927         Acting (other)
#
#                                                  Nominee Additional Info
# 6226   To Hayley Mills for Pollyanna, the most outsta...             NaN
# 6966   To Jon Whiteley for his outstanding juvenile p...             NaN
# 6967   To Vincent Winter for his outstanding juvenile...             NaN
# 7623   To Bobby Driscoll, as the outstanding juvenile...             NaN
# 7745   To Ivan Jandl, for the outstanding juvenile pe...             NaN
# 7860   To James Baskett for his able and heart-warmin...             NaN
# 7974   To Harold Russell for bringing hope and courag...             NaN
# 7975   To Claude Jarman, Jr., outstanding child actor...             NaN
# 8089   To Peggy Ann Garner, outstanding child actress...             NaN
# 8252   To Margaret O'Brien, outstanding child actress...             NaN
# 9165   To Judy Garland for her outstanding performanc...             NaN
# 9318   To Deanna Durbin and Mickey Rooney for their s...             NaN
# 9795   To Shirley Temple, in grateful recognition of ...             NaN
# 10100  To Charles Chaplin, for acting, writing, direc...             NaN
# 10104  To Charles Chaplin, for acting, writing, direc...             NaN

# %% [markdown]
# This is almost identical with the [table](#act_other_table) and [values](#act_other_nominee) we saw above. As stated there, movie titles could be extracted from the "Nominee" column in some rows. Character names are more rarely found.
#
# The trade off of tossing out the character names for most of these rows will be that the records cannot be looked up using them.

# %% [markdown]
# ## What's the best way to handle awards ceremonies that included movies from 2 years (e.g. "1927/28 (1st)")?
#
# I would take the first year. This is an ambiguous choice and not important.
#
# It would be important, though, to be consistent about it.
