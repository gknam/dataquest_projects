# %% [markdown]
# <h1 id="tocheading">Table of Contents</h1>
# <br />
# <div id="toc"><ul class="toc"><li><a href="#1.-Read-data">1. Read data</a><a class="anchor-link" href="#1.-Read-data">¶</a></li><li><a href="#2.-Remove-rows-with-missing-values">2. Remove rows with missing values</a><a class="anchor-link" href="#2.-Remove-rows-with-missing-values">¶</a></li><li><a href="#3.-Draw-scatter-plots:-See-relationship-between-columns">3. Draw scatter plots: See relationship between columns</a><a class="anchor-link" href="#3.-Draw-scatter-plots:-See-relationship-between-columns">¶</a></li><ul class="toc"><li><a href="#3.1.-Sample-size-vs-number-of-reported-employment">3.1. Sample size vs number of reported employment</a><a class="anchor-link" href="#3.1.-Sample-size-vs-number-of-reported-employment">¶</a></li><li><a href="#3.2.-Sample-size-vs-number-of-individuals-in-low-wage-jobs">3.2. Sample size vs number of individuals in low wage jobs</a><a class="anchor-link" href="#3.2.-Sample-size-vs-number-of-individuals-in-low-wage-jobs">¶</a></li><li><a href="#3.3.-Sample-size-vs-Median-earnings">3.3. Sample size vs Median earnings</a><a class="anchor-link" href="#3.3.-Sample-size-vs-Median-earnings">¶</a></li><li><a href="#3.4.-Sample-size-vs-Unemployment-rate">3.4. Sample size vs Unemployment rate</a><a class="anchor-link" href="#3.4.-Sample-size-vs-Unemployment-rate">¶</a></li><li><a href="#3.5.-Number-of-reported-full-time-employment-vs-Median-earnings">3.5. Number of reported full time employment vs Median earnings</a><a class="anchor-link" href="#3.5.-Number-of-reported-full-time-employment-vs-Median-earnings">¶</a></li><li><a href="#3.6.-Number-of-male-graduates-and-Median-earnings">3.6. Number of male graduates and Median earnings</a><a class="anchor-link" href="#3.6.-Number-of-male-graduates-and-Median-earnings">¶</a></li><li><a href="#3.7.-Number-of-female-graduates-and-Median-earnings">3.7. Number of female graduates and Median earnings</a><a class="anchor-link" href="#3.7.-Number-of-female-graduates-and-Median-earnings">¶</a></li><li><a href="#3.8-Popularity-of-major-vs-Median-earnings">3.8 Popularity of major vs Median earnings</a><a class="anchor-link" href="#3.8-Popularity-of-major-vs-Median-earnings">¶</a></li><ul class="toc"><li><a href="#Comments-on-3.3-3.8">Comments on 3.3-3.8</a><a class="anchor-link" href="#Comments-on-3.3-3.8">¶</a></li></ul><li><a href="#3.9.-Proportion-of-women-and-Median-earnings">3.9. Proportion of women and Median earnings</a><a class="anchor-link" href="#3.9.-Proportion-of-women-and-Median-earnings">¶</a></li></ul><li><a href="#4.-Draw-histograms:-See-distribution-of-each-column">4. Draw histograms: See distribution of each column</a><a class="anchor-link" href="#4.-Draw-histograms:-See-distribution-of-each-column">¶</a></li><ul class="toc"><li><a href="#4.1.-Sample-size">4.1. Sample size</a><a class="anchor-link" href="#4.1.-Sample-size">¶</a></li><li><a href="#4.2.-Median-earnings">4.2. Median earnings</a><a class="anchor-link" href="#4.2.-Median-earnings">¶</a></li><li><a href="#4.3.-Number-of-reported-employment">4.3. Number of reported employment</a><a class="anchor-link" href="#4.3.-Number-of-reported-employment">¶</a></li><li><a href="#4.4.-Number-of-reported-full-time-employment">4.4. Number of reported full time employment</a><a class="anchor-link" href="#4.4.-Number-of-reported-full-time-employment">¶</a></li><li><a href="#4.5.-Proportion-of-women">4.5. Proportion of women</a><a class="anchor-link" href="#4.5.-Proportion-of-women">¶</a></li><li><a href="#4.6.-Unemployment-rate">4.6. Unemployment rate</a><a class="anchor-link" href="#4.6.-Unemployment-rate">¶</a></li><li><a href="#4.7.-Number-of-male-graduates">4.7. Number of male graduates</a><a class="anchor-link" href="#4.7.-Number-of-male-graduates">¶</a></li><li><a href="#4.8.-Number-of-female-graduates">4.8. Number of female graduates</a><a class="anchor-link" href="#4.8.-Number-of-female-graduates">¶</a></li></ul><li><a href="#5.-Draw-scatter-matrix-plot:-View-scatter-plots-and-histograms-together">5. Draw scatter matrix plot: View scatter plots and histograms together</a><a class="anchor-link" href="#5.-Draw-scatter-matrix-plot:-View-scatter-plots-and-histograms-together">¶</a></li><ul class="toc"><li><a href="#5.1.-Sample-size-vs-Median-earnings">5.1. Sample size vs Median earnings</a><a class="anchor-link" href="#5.1.-Sample-size-vs-Median-earnings">¶</a></li><li><a href="#5.3.-Sample-size-vs-Median-earnings-vs-Unemployment-rate">5.3. Sample size vs Median earnings vs Unemployment rate</a><a class="anchor-link" href="#5.3.-Sample-size-vs-Median-earnings-vs-Unemployment-rate">¶</a></li><li><a href="#5.3.-Popularity-of-major-vs-Median-earnings">5.3. Popularity of major vs Median earnings</a><a class="anchor-link" href="#5.3.-Popularity-of-major-vs-Median-earnings">¶</a></li><li><a href="#5.4.-Proportion-of-women-and-Median-earnings">5.4. Proportion of women and Median earnings</a><a class="anchor-link" href="#5.4.-Proportion-of-women-and-Median-earnings">¶</a></li><li><a href="#5.5.-Number-of-reported-full-time-employment-vs-Median-earnings">5.5. Number of reported full time employment vs Median earnings</a><a class="anchor-link" href="#5.5.-Number-of-reported-full-time-employment-vs-Median-earnings">¶</a></li></ul><li><a href="#6.-Draw-bar-plots">6. Draw bar plots</a><a class="anchor-link" href="#6.-Draw-bar-plots">¶</a></li><ul class="toc"><li><a href="#6.1.-Percentages-of-women-(ShareWomen)-vs-Majors">6.1. Percentages of women (ShareWomen) vs Majors</a><a class="anchor-link" href="#6.1.-Percentages-of-women-(ShareWomen)-vs-Majors">¶</a></li><ul class="toc"><li><a href="#6.1.1.-10-highest-paying-majors">6.1.1. 10 highest paying majors</a><a class="anchor-link" href="#6.1.1.-10-highest-paying-majors">¶</a></li><li><a href="#6.1.2.-10-lowest-paying-majors.">6.1.2. 10 lowest paying majors.</a><a class="anchor-link" href="#6.1.2.-10-lowest-paying-majors.">¶</a></li></ul><li><a href="#6.2-Unemployment-rate-vs-Majors">6.2 Unemployment rate vs Majors</a><a class="anchor-link" href="#6.2-Unemployment-rate-vs-Majors">¶</a></li><ul class="toc"><li><a href="#6.2.1.-10-highest-paying-majors">6.2.1. 10 highest paying majors</a><a class="anchor-link" href="#6.2.1.-10-highest-paying-majors">¶</a></li><li><a href="#6.2.2.-10-lowest-paying-majors.">6.2.2. 10 lowest paying majors.</a><a class="anchor-link" href="#6.2.2.-10-lowest-paying-majors.">¶</a></li></ul></ul><li><a href="#7.-Further-exploration">7. Further exploration</a><a class="anchor-link" href="#7.-Further-exploration">¶</a></li><ul class="toc"><li><a href="#7.1.-Use-a-grouped-bar-plot-to-compare-the-number-of-men-with-the-number-of-women-in-each-category-of-majors.">7.1. Use a grouped bar plot to compare the number of men with the number of women in each category of majors.</a><a class="anchor-link" href="#7.1.-Use-a-grouped-bar-plot-to-compare-the-number-of-men-with-the-number-of-women-in-each-category-of-majors.">¶</a></li><li><a href="#7.2.-Use-a-box-plot-to-explore-the-distributions-of-median-salaries-and-unemployment-rate.">7.2. Use a box plot to explore the distributions of median salaries and unemployment rate.</a><a class="anchor-link" href="#7.2.-Use-a-box-plot-to-explore-the-distributions-of-median-salaries-and-unemployment-rate.">¶</a></li><li><a href="#7.3.-Use-a-hexagonal-bin-plot-to-visualize-density-within-scatter-plots-from-earlier-in-the-project.">7.3. Use a hexagonal bin plot to visualize density within scatter plots from earlier in the project.</a><a class="anchor-link" href="#7.3.-Use-a-hexagonal-bin-plot-to-visualize-density-within-scatter-plots-from-earlier-in-the-project.">¶</a></li><ul class="toc"><li><a href="#7.3.1.-Sample-size-vs-Median-earnings">7.3.1. Sample size vs Median earnings</a><a class="anchor-link" href="#7.3.1.-Sample-size-vs-Median-earnings">¶</a></li><li><a href="#7.3.2.-Number-of-male-graduates-and-Median-earnings">7.3.2. Number of male graduates and Median earnings</a><a class="anchor-link" href="#7.3.2.-Number-of-male-graduates-and-Median-earnings">¶</a></li><li><a href="#7.3.3.-Number-of-female-graduates-and-Median-earnings">7.3.3. Number of female graduates and Median earnings</a><a class="anchor-link" href="#7.3.3.-Number-of-female-graduates-and-Median-earnings">¶</a></li></ul></ul></ul></div>

# %% [markdown]
# Project guide: https://www.dataquest.io/m/146/guided-project%3A-visualizing-earnings-based-on-college-majors
#
# Solution by DataQuest: https://github.com/dataquestio/solutions/blob/master/Mission146Solutions.ipynb
#
# <br /><br />
#
# This is a guided project at DataQuest for practicing **data visualisation using pandas**.
#
# This project uses dataset downloaded from http://bit.ly/2hBPbDn.
#
# # 1. Read data

# %%
import pandas as pd
import matplotlib.pyplot as plt

from IPython.display import display

# %matplotlib inline

# read in data
recent_grads = pd.read_csv("recent-grads.csv")

# display first row of data
print(recent_grads.iloc[1])
# Out:
# Rank                                                 2
# Major_code                                        2416
# Major                   MINING AND MINERAL ENGINEERING
# Total                                              756
# Men                                                679
# Women                                               77
# Major_category                             Engineering
# ShareWomen                                    0.101852
# Sample_size                                          7
# Employed                                           640
# Full_time                                          556
# Part_time                                          170
# Full_time_year_round                               388
# Unemployed                                          85
# Unemployment_rate                             0.117241
# Median                                           75000
# P25th                                            55000
# ...

# %%
# display first 5 rows of data
print("First 5 rows")
display(recent_grads.head(5))
print("\n")


# display last 5 rows of data
print("Last 5 rows")
display(recent_grads.tail(5))
# Out:
# First 5 rows
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
# ...

# %%
# display summary of data
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %% [markdown]
# # 2. Remove rows with missing values

# %%
# get number of rows
raw_data_count = recent_grads.shape[0]

# drop rows containing missing values
recent_grads = recent_grads.dropna()

# update number of rows
cleaned_data_count = recent_grads.shape[0]

print("Number of rows in raw data: " + str(raw_data_count))
print("Number of rows in cleaned data: " + str(cleaned_data_count))
# Out:
# Number of rows in raw data: 173
# Number of rows in cleaned data: 172

# %% [markdown]
# # 3. Draw scatter plots: See relationship between columns
#
# ## 3.1. Sample size vs number of reported employment

# %%
figsize = (7, 5)

recent_grads.plot(x="Sample_size", y="Employed", kind="scatter", \
                  title="Employed vs Sample_size", figsize=figsize)

# %% [markdown]
# Bigger sample size meant greater number of reported employment.
#
# ## 3.2. Sample size vs number of individuals in low wage jobs

# %%
ax = recent_grads.plot(x="Employed", y="Low_wage_jobs", \
                       kind="scatter", figsize=figsize)
ax.set_title("Employed vs Low_wage_jobs")
# Out:
# Text(0.5, 1.0, 'Employed vs Low_wage_jobs')

# %% [markdown]
# Increased employment also meant greater number of individuals in low wage jobs.
#
# ## 3.3. Sample size vs Median earnings

# %%
recent_grads.plot(x="Sample_size", y="Median", kind="scatter", \
                 figsize=figsize, title="Sample_size vs Median")

# %% [markdown]
# See [Comments on 3.3-3.8](#Comments-on-3.3-3.8).
#
# ## 3.4. Sample size vs Unemployment rate

# %%
ax = recent_grads.plot(x="Sample_size", y="Unemployment_rate", \
                  kind="scatter", figsize=figsize)

ax.set_title("Sample_size vs Unemployment_rate")
# Out:
# Text(0.5, 1.0, 'Sample_size vs Unemployment_rate')

# %% [markdown]
# See [Comments on 3.3-3.8](#Comments-on-3.3-3.8).
#
# ## 3.5. Number of reported full time employment vs Median earnings

# %%
recent_grads.plot(x="Full_time", y="Median", kind="scatter", \
                  figsize=figsize, title="Full_time vs Median")

# %% [markdown]
# See [Comments on 3.3-3.8](#Comments-on-3.3-3.8).
#
# ## 3.6. Number of male graduates and Median earnings

# %%
ax = recent_grads.plot(x="Men", y="Median", kind="scatter", \
                       figsize=figsize)
ax.set_title("Men vs Median")
# Out:
# Text(0.5, 1.0, 'Men vs Median')

# %% [markdown]
# See [Comments on 3.3-3.8](#Comments-on-3.3-3.8).
#
# ## 3.7. Number of female graduates and Median earnings

# %%
recent_grads.plot(x="Women", y="Median", kind="scatter", \
                  figsize=figsize, title="Women vs Median")

# %% [markdown]
# ## 3.8 Popularity of major vs Median earnings

# %%
recent_grads.plot(x="Total", y="Median", kind="scatter", \
                  figsize=figsize, title="Total vs Median")

# %% [markdown]
# ### Comments on 3.3-3.8
#
# Median earnings narrowed when the value in the other variable increased. This seems to reflect (1) that bigger value means bigger sample size and (2) that bigger sample size means less variability in the data.

# %% [markdown]
# ## 3.9. Proportion of women and Median earnings

# %%
recent_grads.plot(x="ShareWomen", y="Median", kind="scatter", \
                  figsize=figsize, title="ShareWomen vs Median")

# %% [markdown]
# Median earnings decreased as proportion of women increased.
#
# # 4. Draw histograms: See distribution of each column
#
# ## 4.1. Sample size

# %%
# set variables for all histograms
hist_ylabel = "Frequency"
bins = 100
edgecolor = "black"


def distribution_and_summary(dataframe, columnLabel):
    # set variables for the column
    col = dataframe[columnLabel]

    # set histogram range giving leeways to min and max
    # values of the column
    col_min = col.min()
    col_max = col.max()
    col_range = col_max - col_min
    hist_range_leeway = col_range * 0.01
    hist_range = (col_min - hist_range_leeway, \
                  col_max + hist_range_leeway)

    # create figure
    fig = plt.figure(figsize=(5, 10))
    
    # draw box plot
    ax1 = fig.add_subplot(2, 1, 1)
    ax1 = col.plot(kind="box", vert=False)

    # draw histogram
    ax2 = fig.add_subplot(2, 1, 2)
    ax2 = col.hist(bins=bins, range=hist_range, edgecolor=edgecolor)

    # tweak histogram
    ax2.set_xlabel(columnLabel)
    ax2.set_ylabel(hist_ylabel)
    ax2.set_title(columnLabel + " distribution")

    # display summary description
    display(col.describe())

# draw plot
distribution_and_summary(recent_grads, "Sample_size")
# Out:
# count     172.000000
# mean      357.941860
# std       619.680419
# min         2.000000
# 25%        42.000000
# 50%       131.000000
# 75%       339.000000
# max      4212.000000
# Name: Sample_size, dtype: float64

# %% [markdown]
# Sample size distribution is right-skewed. Half of the majors had the sample size equal to or less than 131.
#
# ## 4.2. Median earnings

# %%
distribution_and_summary(recent_grads, "Median")
# Out:
# count       172.000000
# mean      40076.744186
# std       11461.388773
# min       22000.000000
# 25%       33000.000000
# 50%       36000.000000
# 75%       45000.000000
# max      110000.000000
# Name: Median, dtype: float64

# %% [markdown]
# Median earnings peaked at around mid-35K, being positively skewed.
#
# ## 4.3. Number of reported employment

# %%
distribution_and_summary(recent_grads, "Employed")
# Out:
# count       172.00000
# mean      31355.80814
# std       50777.42865
# min           0.00000
# 25%        3734.75000
# 50%       12031.50000
# 75%       31701.25000
# max      307933.00000
# Name: Employed, dtype: float64

# %% [markdown]
# Number of employment is also positively skewed.
#
# ## 4.4. Number of reported full time employment

# %%
distribution_and_summary(recent_grads, "Full_time")
# Out:
# count       172.000000
# mean      26165.767442
# std       42957.122320
# min         111.000000
# 25%        3181.000000
# 50%       10073.500000
# 75%       25447.250000
# max      251540.000000
# Name: Full_time, dtype: float64

# %% [markdown]
# Another positive skew is observed here. The shape of distribution is very similar to that of the "Employed".
#
# ## 4.5. Proportion of women

# %%
distribution_and_summary(recent_grads, "ShareWomen")
# Out:
# count    172.000000
# mean       0.522223
# std        0.231205
# min        0.000000
# 25%        0.336026
# 50%        0.534024
# 75%        0.703299
# max        0.968954
# Name: ShareWomen, dtype: float64

# %% [markdown]
# Gender distribution in each mejor seems to be almost equal.
#
# The median is slighly greater than 0.5. Therefore, there are slighly more male-dominant majors than its counter part.

# %% [markdown]
# ## 4.6. Unemployment rate

# %%
distribution_and_summary(recent_grads, "Unemployment_rate")
# Out:
# count    172.000000
# mean       0.068024
# std        0.030340
# min        0.000000
# 25%        0.050261
# 50%        0.067544
# 75%        0.087247
# max        0.177226
# Name: Unemployment_rate, dtype: float64

# %% [markdown]
# Unemployment rate is symmetrically distribiuted in a bell shape.
#
# ## 4.7. Number of male graduates

# %%
distribution_and_summary(recent_grads, "Men")
# Out:
# count       172.000000
# mean      16723.406977
# std       28122.433474
# min         119.000000
# 25%        2177.500000
# 50%        5434.000000
# 75%       14631.000000
# max      173809.000000
# Name: Men, dtype: float64

# %% [markdown]
# ## 4.8. Number of female graduates

# %%
distribution_and_summary(recent_grads, "Women")
# Out:
# count       172.000000
# mean      22646.674419
# std       41057.330740
# min           0.000000
# 25%        1778.250000
# 50%        8386.500000
# 75%       22553.750000
# max      307087.000000
# Name: Women, dtype: float64

# %% [markdown]
# Most men and women appear to get paid less than $20K.

# %% [markdown]
# # 5. Draw scatter matrix plot: View scatter plots and histograms together
#
# pandas allow viewing histograms together with scatter plots. Some examples are as follows.
#
# ## 5.1. Sample size vs Median earnings

# %%
from pandas.plotting import scatter_matrix

scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f83ae593be0>,
# ...
#       dtype=object)

# %% [markdown]
# ## 5.3. Sample size vs Median earnings vs Unemployment rate

# %%
scatter_matrix(recent_grads[["Sample_size", "Median", "Unemployment_rate"]], figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f83aea130f0>,
# ...
#       dtype=object)

# %% [markdown]
# ## 5.3. Popularity of major vs Median earnings

# %%
scatter_matrix(recent_grads[["Total", "Median"]], figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f83ae721f28>,
# ...
#       dtype=object)

# %% [markdown]
# ## 5.4. Proportion of women and Median earnings

# %%
scatter_matrix(recent_grads[["ShareWomen", "Median"]], figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f83ae9f6f60>,
# ...
#       dtype=object)

# %% [markdown]
# ## 5.5. Number of reported full time employment vs Median earnings

# %%
scatter_matrix(recent_grads[["Full_time", "Median"]], figsize=(10, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f83aecb2c18>,
# ...
#       dtype=object)

# %% [markdown]
# # 6. Draw bar plots
#
# Use **DataFram.plot(kind="bar")**

# %%
recent_grads[:5]["Women"].plot(kind="bar")

# %% [markdown]
# Now use **DataFrame.plot.bar()** for better labels.

# %%
recent_grads[:5].plot.bar(x="Major", y="Women")

# %% [markdown]
# ## 6.1. Percentages of women (ShareWomen) vs Majors
#
# ### 6.1.1. 10 highest paying majors

# %%
paid_top10 = recent_grads.sort_values(by="Median", ascending=False).head(10)
display(paid_top10[["Major", "ShareWomen", "Median"]])
paid_top10.sort_values(by="ShareWomen").plot.bar(x="Major", y="ShareWomen")
# Out:
#                                         Major  ShareWomen  Median
# 0                       PETROLEUM ENGINEERING    0.120564  110000
# 1              MINING AND MINERAL ENGINEERING    0.101852   75000
# 2                   METALLURGICAL ENGINEERING    0.153037   73000
# 3   NAVAL ARCHITECTURE AND MARINE ENGINEERING    0.107313   70000
# 4                        CHEMICAL ENGINEERING    0.341631   65000
# 5                         NUCLEAR ENGINEERING    0.144967   65000
# 6                           ACTUARIAL SCIENCE    0.441356   62000
# 7                  ASTRONOMY AND ASTROPHYSICS    0.535714   62000
# 10                       COMPUTER ENGINEERING    0.199413   60000
# 13                          MATERIALS SCIENCE    0.310820   60000

# %% [markdown]
# ### 6.1.2. 10 lowest paying majors.

# %%
paid_bottom10 = recent_grads.sort_values(by="Median", ascending=False).tail(10)
display(paid_bottom10[["Major", "ShareWomen", "Median"]])
paid_bottom10.sort_values(by="ShareWomen", ascending=False).plot.bar(x="Major", y="ShareWomen")
# Out:
#                            Major  ShareWomen  Median
# 164    EARLY CHILDHOOD EDUCATION    0.968954   28000
# 162  ANTHROPOLOGY AND ARCHEOLOGY    0.707136   28000
# 165      OTHER FOREIGN LANGUAGES    0.690111   27500
# 166       DRAMA AND THEATER ARTS    0.666119   27000
# 167     COMPOSITION AND RHETORIC    0.629505   27000
# 168                      ZOOLOGY    0.637293   26000
# 169       EDUCATIONAL PSYCHOLOGY    0.817099   25000
# 170          CLINICAL PSYCHOLOGY    0.799859   25000
# 171        COUNSELING PSYCHOLOGY    0.798746   23400
# 172              LIBRARY SCIENCE    0.877960   22000

# %% [markdown]
# ## 6.2 Unemployment rate vs Majors
#
# ### 6.2.1. 10 highest paying majors

# %%
display(paid_top10[["Major", "Unemployment_rate", "Median"]])
paid_top10.sort_values(by="Unemployment_rate").plot.bar(x="Major", y="Unemployment_rate")
# Out:
#                                         Major  Unemployment_rate  Median
# 0                       PETROLEUM ENGINEERING           0.018381  110000
# 1              MINING AND MINERAL ENGINEERING           0.117241   75000
# 2                   METALLURGICAL ENGINEERING           0.024096   73000
# 3   NAVAL ARCHITECTURE AND MARINE ENGINEERING           0.050125   70000
# 4                        CHEMICAL ENGINEERING           0.061098   65000
# 5                         NUCLEAR ENGINEERING           0.177226   65000
# 6                           ACTUARIAL SCIENCE           0.095652   62000
# 7                  ASTRONOMY AND ASTROPHYSICS           0.021167   62000
# 10                       COMPUTER ENGINEERING           0.065409   60000
# 13                          MATERIALS SCIENCE           0.023043   60000

# %% [markdown]
# ### 6.2.2. 10 lowest paying majors.

# %%
display(paid_bottom10[["Major", "Unemployment_rate", "Median"]])
paid_bottom10.sort_values(by="Unemployment_rate", ascending=False).plot.bar(x="Major", y="Unemployment_rate")
# Out:
#                            Major  Unemployment_rate  Median
# 164    EARLY CHILDHOOD EDUCATION           0.040105   28000
# 162  ANTHROPOLOGY AND ARCHEOLOGY           0.102792   28000
# 165      OTHER FOREIGN LANGUAGES           0.107116   27500
# 166       DRAMA AND THEATER ARTS           0.077541   27000
# 167     COMPOSITION AND RHETORIC           0.081742   27000
# 168                      ZOOLOGY           0.046320   26000
# 169       EDUCATIONAL PSYCHOLOGY           0.065112   25000
# 170          CLINICAL PSYCHOLOGY           0.149048   25000
# 171        COUNSELING PSYCHOLOGY           0.053621   23400
# 172              LIBRARY SCIENCE           0.104946   22000

# %% [markdown]
# # 7. Further exploration
#
# ## 7.1. Use a grouped bar plot to compare the number of men with the number of women in each category of majors.

# %%
import numpy as np

# Code from Hector Page at Q & A of http://bit.ly/2itvOgU
pivot_mc_m_w = recent_grads.pivot_table(index="Major_category", values=["Men", "Women"], aggfunc=np.sum)

# Sort by "Women"
pivot_mc_m_w = pivot_mc_m_w.sort_values(by="Women")

pivot_mc_m_w.plot.bar()
plt.show()

# %% [markdown]
# ## 7.2. Use a box plot to explore the distributions of median salaries and unemployment rate.
#
# For median salaries distribution, see [this](#4.2.-Median-earnings).
# For unemployment rate distribution, see [this](#4.6.-Unemployment-rate).
#
# ## 7.3. Use a hexagonal bin plot to visualize density within scatter plots from earlier in the project.
# [**Hexbin plots** can be a useful alternative to scatter plots if your data are too dense to plot each point individually.](https://pandas.pydata.org/pandas-docs/version/0.18.1/visualization.html#hexagonal-bin-plot)
#
# ### 7.3.1. Sample size vs Median earnings

# %%
ax = recent_grads.plot.hexbin(x="Sample_size", y="Median", gridsize=50)

# %% [markdown]
# ### 7.3.2. Number of male graduates and Median earnings

# %%
recent_grads.plot.hexbin(x="Men", y="Median", gridsize=50)

# %% [markdown]
# ### 7.3.3. Number of female graduates and Median earnings

# %%
recent_grads.plot.hexbin(x="Women", y="Median", gridsize=50)
